# %% [markdown]
# ## Purpose of This Analysis
#
# The purpose of analyzing the Air Crashes dataset from 1908 to 2023 is to uncover patterns, trends, and insights related to aviation incidents over time. This analysis serves several key objectives:
#
# - **Understand Historical Trends**: Examine how air crash frequency and severity have evolved across decades, highlighting the impact of technological advancement, regulatory improvements, and safety standards.
#
# - **Identify High-Risk Factors**: Detect common factors associated with air incidents, such as particular months, aircraft types, countries, or operators, to better understand potential risk zones.
#
# - **Quantify Human Impact**: Assess the total number of fatalities both onboard and on the ground to understand the human cost of air crashes.
#
# - **Support Aviation Safety**: Provide data-driven evidence that can guide aviation authorities, operators, and policymakers in improving flight safety and reducing future crash occurrences.
#
# - **Build Data Literacy**: Serve as a case study in applying data cleaning, statistical analysis, and visualization techniques to a real-world, time-series dataset with both categorical and numerical features.
#
# Ultimately, this analysis aims to transform raw crash records into meaningful insights that can inform both public understanding and future improvements in the aviation industry.

# %% [markdown]
# ## 1. Importing Libraries
#
# We start by importing essential Python libraries for data analysis and visualization.
#
# - `pandas` for handling datasets
# - `numpy` for numerical operations
# - `plotly` for interactive charts
# - `ipywidgets` for dropdowns and sliders (for interactivity in Jupyter)
# - `os` for file path management

# %%
# Import Libararies
import pandas as pd
import numpy as np
import os
import plotly.express as px
from plotly.subplots import make_subplots
import plotly.graph_objects as go
import os

# %% [markdown]
# ## Define and Create Directory Paths
#
# To ensure reproducibility andorganized storage, we programmatically create directories for:
#
# - **raw data**
# - **processed data**
# - **results**
# - **documentation**
#
# These directories will store intermediate and final outputs for reproducibility.

# %%
# Get working directory
current_dir= os.getcwd()
# Go one directory up to the root directory
project_root_dir= os.path.dirname(current_dir)
project_root_dir
# Define paths to docs folder
data_dir= os.path.join(project_root_dir,'Data')
raw_dir= os.path.join(data_dir,'Raw')
processed_dir=os.path.join(data_dir,'Processed')
results_dir=os.path.join(project_root_dir,'Results')
docs_dir=os.path.join(project_root_dir,'Docs')
notebook_dir= os.path.join(project_root_dir,'Notebooks')

# %% [markdown]
# ## 2. Loading and Exploring the Dataset
#
# We load the cleaned aircrash dataset from the Notebooks directory and inspect the first few rows.
#
# The dataset includes:
# - Year, month, day
# - Location and country
# - Aircraft type and manufacturer
# - Operator type
# - Number of people aboard, fatalities (in air and on ground)

# %%
aircrash_data_filename= os.path.join(processed_dir,"Aircrash_file.csv")
df= pd.read_csv(aircrash_data_filename, na_values='?', skipinitialspace=True)
df.head()
# Out:
#    Year Quarter      Month  Day  Country/Region Aircraft Manufacturer  \
# 0  1908   Qtr 3  September   17   United States                Wright
# 1  1909   Qtr 3  September    7          France                Wright
# 2  1912   Qtr 3       July   12         Unknown               Unknown
# 3  1913   Qtr 3     August    6  United Kingdom               Curtiss
# 4  1913   Qtr 3  September    9         Unknown              Zeppelin
#
#                  Aircraft                                  Location  \
# 0        Wright Flyer III                                  virginia
# 1       Wright ByplaneSC1                                    france
# 2               Dirigible                                  atlantic
# 3        Curtiss seaplane                          victoria british
# 4  Zeppelin L 1 (airship)  over the north seamilitary - german navy
#
#                            Operator  Sum of Ground  Sum of Fatalities (air)  \
# ...

# %% [markdown]
# This cell loads the `Aircrash_file.csv` (presumably the cleaned dataset from your previous notebook) into a pandas DataFrame named `df`.
# - `os.path.join(processed_dir, "Aircrash_file.csv")`: Constructs the full file path to the CSV file located in the `processed` data directory.
# - `na_values='?'`: Specifies that `?` characters in the dataset should be treated as `NaN` (Not a Number) or missing values during import.
# - `skipinitialspace=True`: This argument helps in cleaning string columns by removing initial spaces after delimiters.
# - `df.head()`: Displays the first 5 rows of the DataFrame, providing an initial overview of the loaded data, including the columns and a sample of their values.

# %% [markdown]
# ## Dataset Dimensions and Data Types

# %% [markdown]
# Here, we examine the structure of the dataset:
# This cell displays the shape of the DataFrame `df`, which returns a tuple representing the number of rows and columns. This is a quick way to verify the dimensions of the loaded dataset. The output `(5030, 14)` indicates that the DataFrame has 5030 rows (representing individual air crash incidents) and 14 columns (representing different attributes of each incident).

# %%
df.shape
# Out:
# (5030, 14)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5030 entries, 0 to 5029
# Data columns (total 14 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Year                     5030 non-null   int64
#  1   Quarter                  5030 non-null   object
#  2   Month                    5030 non-null   object
#  3   Day                      5030 non-null   int64
#  4   Country/Region           5030 non-null   object
#  5   Aircraft Manufacturer    5030 non-null   object
#  6   Aircraft                 5020 non-null   object
#  7   Location                 5030 non-null   object
#  8   Operator                 5030 non-null   object
#  9   Sum of Ground            5030 non-null   int64
#  10  Sum of Fatalities (air)  5030 non-null   int64
#  11  Sum of Aboard            5030 non-null   int64
#  12  Month_num                5030 non-null   int64
#  13  Date                     5030 non-null   object
# ...

# %% [markdown]
# ### Summary Statistics: Numerical Variables

# %% [markdown]
# This section explores the distribution of key numerical variables in the dataset, providing insights into central tendencies, variability, and patterns that may reflect broader operational or socio-economic dynamics.
#
# **Age**
# The age of individuals ranges from 17 to 90, with a mean of approximately 38.6 years. The distribution is slightly right-skewed, meaning most individuals fall in the younger to middle-aged categories, with fewer represented in older brackets. This age pattern is typical of labor force datasets, where participation tends to decline past retirement age. The skew suggests that younger individuals are more commonly captured, possibly due to employment dynamics or survey design.
#
# **Capital Gain / Capital Loss**
# Both capital gain and capital loss variables are **highly skewed**, with a large proportion of values concentrated at 0. The 75th percentile being zero implies that most individuals do not report any capital-related income or losses. However, the **maximum capital gain** reaches $99,999, signaling that a small subset of the population possesses significant investment income. These features reveal stark economic inequality and highlight that individuals with non-zero values likely represent higher-income groups with investment exposure.
#
# **Hours Worked per Week**
# Work hours vary from 1 to 99 hours weekly. The **median** is 40, which aligns with standard full-time employment. The **mean** is slightly higher (around 40.4 hours), suggesting a slight right skew driven by individuals working long hours. The **mode** also falls at 40 hours, reinforcing the dominance of full-time schedules. A noticeable minority reports working fewer than 20 hours or more than 45, reflecting diverse work arrangements — including part-time employment, self-employment, and informal labor — potentially influenced by economic necessity or flexible job structures.
#
# These numerical patterns provide foundational context for further analysis, especially when exploring correlations with outcomes such as income, employment type, or education level.

# %%
df.describe(include='object')
# Out:
#        Quarter     Month Country/Region Aircraft Manufacturer      Aircraft  \
# count     5030      5030           5030                  5030          5020
# unique       4        12             60                   285          3510
# top      Qtr 4  December        Unknown               Douglas  Boeing B 737
# freq      1368       497           3547                   995            73
#
#              Location Operator        Date
# count            5030     5030        5030
# unique           4165     2625        4598
# top     moscow russia  Unknown  2001-09-11
# freq               16      234           4

# %% [markdown]
# ### Summary Statistics: Categorical Variables

# %% [markdown]
# **Year**
# The dataset spans from 1908 to 2023, covering over a century of aviation history. The frequency of recorded crashes increases notably after the 1950s, peaking around the 1970s and 1980s — a period of major aviation expansion. Post-2000 shows a gradual decline, likely due to improved technology, safety regulations, and training.
#
# **Quarter**
# Most crashes occur in Q3 (~30%) and Q2 (~27%), aligning with seasonal travel peaks in mid-year months. Q1 and Q4 see slightly fewer incidents, which may be attributed to lower flight volumes or weather-based caution during winter months.
#
# **Month**
# July and August collectively account for a significant portion of crashes, each contributing around 9–10% of total incidents. This reflects the high global air traffic during summer holidays. In contrast, February records the fewest crashes, possibly due to fewer travel demands and shorter month duration.
#
# **Day**
# Crashes are fairly evenly distributed across days of the month, with minor spikes around the 15th and 31st. This may suggest routine operations rather than specific calendar dates influencing crash frequency.
#
# **Country/Region**
# The United States has the highest number of recorded incidents by a large margin, followed by Russia, Canada, and Brazil. This is expected due to flight volume and geography. Some countries may appear frequently due to historic underreporting or geopolitical changes (e.g., USSR, Yugoslavia).
#
# **Aircraft Manufacturer**
# The leading aircraft manufacturers involved in incidents are Boeing, Airbus, and McDonnell Douglas. Boeing dominates, especially in the second half of the 20th century, reflecting its market share and fleet presence. Smaller manufacturers such as Tupolev and Antonov appear mainly in regional or military contexts.
#
# **Aircraft**
# Aircraft models such as the Boeing 737, DC-3, and Airbus A320 show high frequency, indicating their widespread use in commercial fleets. Older models like the DC-3 appear more in early decades, while modern jets dominate recent decades.
#
# **Location**
# Crash locations are widely distributed but tend to cluster near major airports, mountainous terrain, or regions with harsh weather. Urban peripheries and remote zones often host higher crash records due to navigational or environmental challenges.
#
# **Operator**
# National carriers like American Airlines, Aeroflot, and Air France have higher incident counts, partially due to their long operational history and large fleet size. Many military and charter operators also appear, though often in localized contexts.
#
# **Onboard and Fatalities Summary**
# Onboard counts range widely, from small aircraft (less than 10 people) to large commercial jets (over 300). Fatalities generally scale with onboard numbers. A small but notable proportion of crashes result in no fatalities, underscoring the role of crew training and emergency response. Ground fatalities are less frequent but can be catastrophic in urban or airport-adjacent crashes.

# %%
df['Year'].value_counts(normalize=True)
# Out:
# Year
# 1946    0.017495
# 1989    0.016501
# 1947    0.016302
# 1962    0.015706
# 1948    0.015507
#           ...
# 2023    0.000398
# 1915    0.000398
# 1909    0.000199
# 1912    0.000199
# 1908    0.000199
# Name: proportion, Length: 113, dtype: float64

# %%
df['Quarter'].value_counts(normalize=True)
# Out:
# Quarter
# Qtr 4    0.271968
# Qtr 3    0.265010
# Qtr 1    0.249105
# Qtr 2    0.213917
# Name: proportion, dtype: float64

# %%
df['Month'].value_counts(normalize=True)
# Out:
# Month
# December     0.098807
# January      0.092247
# September    0.090060
# August       0.089861
# November     0.088072
# July         0.085089
# October      0.085089
# March        0.084891
# June         0.072962
# February     0.071968
# May          0.071571
# April        0.069384
# Name: proportion, dtype: float64

# %%
df['Day'].value_counts(normalize=True)
# Out:
# Day
# 8     0.036779
# 15    0.036183
# 24    0.035388
# 27    0.035189
# 10    0.034990
# 14    0.034592
# 9     0.034394
# 2     0.034394
# 11    0.034195
# 3     0.034195
# 21    0.034195
# 22    0.033400
# 6     0.033002
# 17    0.032803
# 12    0.032803
# 18    0.032406
# 4     0.032207
# 20    0.031610
# 29    0.031213
# 26    0.031213
# 16    0.031014
# 19    0.031014
# 23    0.030815
# 28    0.030417
# 25    0.030417
# 13    0.030417
# 5     0.029821
# 30    0.029821
# 7     0.029026
# 1     0.029026
# 31    0.023062
# Name: proportion, dtype: float64

# %%
df['Country/Region'].value_counts(normalize=True)
# Out:
# Country/Region
# Unknown                     0.705169
# United States               0.161630
# Brazil                      0.032803
# India                       0.023658
# China                       0.018091
# Canada                      0.014911
# Spain                       0.012525
# United Kingdom              0.008946
# Serbia                      0.002386
# Portugal                    0.001590
# Italy                       0.001392
# France                      0.001392
# Japan                       0.001392
# Indonesia                   0.001193
# Australia                   0.000994
# Philippines                 0.000795
# Mexico                      0.000795
# Malaysia                    0.000398
# Colombia                    0.000398
# Argentina                   0.000398
# Cameroon                    0.000398
# Zimbabwe                    0.000398
# Sweden                      0.000398
# Netherlands                 0.000398
# Bulgaria                    0.000398
# ...

# %%
df['Aircraft Manufacturer'].value_counts(normalize=True)
# Out:
# Aircraft Manufacturer
# Douglas                0.197813
# Boeing                 0.080915
# Lockheed               0.065408
# De Havilland           0.058648
# Antonov                0.057256
#                          ...
# Volpar                 0.000199
# Britten-Norman         0.000199
# Cant                   0.000199
# De Havilland Canada    0.000199
# Socata                 0.000199
# Name: proportion, Length: 285, dtype: float64

# %%
df['Aircraft'].value_counts(normalize=True)
# Out:
# Aircraft
# Boeing B 737                       0.014542
# Boeing B 727                       0.011355
# Boeing B 707                       0.010159
# McDonnell Douglas DC 9             0.008367
# Douglas C 47A                      0.007968
#                                      ...
# Lockheed 18 LodestarN300E          0.000199
# Douglas DC 7                       0.000199
# Douglas C 124C / Fairchild C       0.000199
# Junkers JU 52/3mHC                 0.000199
# Embraer EMB 110P1 BandeirantePT    0.000199
# Name: proportion, Length: 3510, dtype: float64

# %%
df['Location'].value_counts(normalize=True)
# Out:
# Location
# moscow russia                        0.003181
# manila philippines                   0.002982
# new york new                         0.002982
# cairo egypt                          0.002584
# sao paulo brazil                     0.002584
#                                        ...
# nantucket massachusetts              0.000199
# near chita russia                    0.000199
# off guammilitary - u.s. air force    0.000199
# sasnashen russia                     0.000199
# brazil                               0.000199
# Name: proportion, Length: 4165, dtype: float64

# %%
df['Operator'].value_counts(normalize=True)
# Out:
# Operator
# Unknown                                    0.046521
# Aeroflot                                   0.037376
# Force Air U.S. - Military                  0.018290
# France Air                                 0.011332
# Lufthansa Deutsche                         0.011332
#                                              ...
# Airlines SamoaPolynesian                   0.000199
# Air Laos                                   0.000199
# New York          Falls Mohawk Airlines    0.000199
# Canada Austin Airways                      0.000199
# Aerotaxi Manaus                            0.000199
# Name: proportion, Length: 2625, dtype: float64

# %%
df['Sum of Ground'].value_counts(normalize=True)
# Out:
# Sum of Ground
# 0       0.949901
# 1       0.012326
# 2       0.007157
# 3       0.004374
# 4       0.003181
# 5       0.002386
# 7       0.001988
# 8       0.001789
# 6       0.001193
# 10      0.001193
# 14      0.000994
# 11      0.000795
# 13      0.000795
# 12      0.000795
# 19      0.000795
# 44      0.000795
# 22      0.000795
# 24      0.000596
# 20      0.000596
# 35      0.000398
# 25      0.000398
# 125     0.000398
# 15      0.000398
# 30      0.000398
# 37      0.000398
# 2750    0.000398
# 32      0.000199
# 45      0.000199
# 39      0.000199
# 18      0.000199
# 225     0.000199
# 49      0.000199
# 9       0.000199
# 78      0.000199
# 40      0.000199
# 50      0.000199
# 31      0.000199
# 113     0.000199
# 71      0.000199
# 33      0.000199
# 23      0.000199
# 87      0.000199
# 17      0.000199
# 29      0.000199
# 16      0.000199
# 36      0.000199
# 58      0.000199
# 63      0.000199
# 53      0.000199
# 85      0.000199
# ...

# %%
df['Sum of Fatalities (air)'].value_counts(normalize=True)
# Out:
# Sum of Fatalities (air)
# 1      0.076342
# 2      0.075149
# 3      0.072565
# 4      0.048708
# 5      0.046918
#          ...
# 259    0.000199
# 144    0.000199
# 171    0.000199
# 223    0.000199
# 224    0.000199
# Name: proportion, Length: 199, dtype: float64

# %%
df['Sum of Aboard'].value_counts(normalize=True)
# Out:
# Sum of Aboard
# 3      0.055666
# 2      0.048907
# 4      0.040557
# 5      0.037972
# 10     0.035785
#          ...
# 356    0.000199
# 258    0.000199
# 259    0.000199
# 290    0.000199
# 190    0.000199
# Name: proportion, Length: 244, dtype: float64

# %% [markdown]
# **Cell Explanation:**
# This cell calculates key summary statistics and then visualizes them using Plotly `go.Indicator` objects, creating a dashboard-like overview of the dataset.
#
# **Calculations:**
# - `aircrafts = df['Aircraft'].nunique()`: Counts the number of unique aircraft types involved in crashes.
# - `crashes = len(df)`: Determines the total number of recorded crashes.
# - `countries = df['Country/Region'].nunique()`: Identifies the number of distinct countries/regions where crashes occurred.
# - `fatalities_air = df['Sum of Fatalities (air)'].sum()`: Calculates the total number of fatalities in the air across all crashes.
# - `fatalities_ground = df['Sum of Ground'].sum()`: Calculates the total number of fatalities on the ground across all crashes.
# - `aboard_total = df['Sum of Aboard'].sum()`: Sums the total number of people who were aboard the aircraft across all crashes.
# - `aboard_avg = df['Sum of Aboard'].mean()`: Computes the average number of people aboard per crash.
#
# **Plotly Visualization (`make_subplots` and `go.Indicator`):**
# - `make_subplots`: Creates a 2x3 grid for the indicators.
# - `go.Indicator`: Each `add_trace` line adds a new indicator.
#     - **Row 1, Col 1: Total Fatalities (Air)**: Shows the cumulative number of air fatalities.
#     - **Row 1, Col 2: Total Fatalities (Ground)**: Shows the cumulative number of ground fatalities.
#     - **Row 1, Col 3: Total Crashes**: Displays the total count of crash incidents.
#     - **Row 2, Col 1: Unique Aircrafts**: Shows the variety of aircraft involved.
#     - **Row 2, Col 2: Countries Involved**: Indicates the global spread of the incidents.
#     - **Row 2, Col 3: Avg Aboard per Crash**: Provides the average number of people on board for each crash.
#
# **Layout Updates:**
# - `height=400`, `width=1000`: Sets the dimensions of the figure.
# - `template='presentation'`: Applies a clean, presentable theme.
# - `paper_bgcolor`, `plot_bgcolor`: Sets transparent backgrounds for better integration.
#
# **Interpretation of the Graph:**
# The dashboard provides a quick summary of the air crash dataset:
# - There have been **111,784 total fatalities in the air** and **8,483 on the ground**, indicating that the vast majority of fatalities occur in-flight.
# - A total of **5,008 crashes** have been recorded.
# - These crashes involved **3,494 unique aircraft types** and occurred across **60 countries**.
# - On average, approximately **31.15 people were aboard** each crashed aircraft.
# This snapshot helps in understanding the scale and key statistics of air incidents.
#
# **Saving the Figure:**
# The graph is saved in three formats: JPG, PNG, and HTML, to the `results_dir` for easy sharing and further use.

# %%
aircrafts = df['Aircraft'].nunique()
crashes = len(df)
countries = df['Country/Region'].nunique()
fatalities_air = df['Sum of Fatalities (air)'].sum()
fatalities_ground = df['Sum of Ground'].sum()
aboard_total = df['Sum of Aboard'].sum()

# 2 rows x 3 columns
fig = make_subplots(rows=2, cols=3, specs=[[{'type': 'indicator'}]*3]*2, row_heights=[0.60, 0.55])

fig.add_trace(go.Indicator(
    mode="number",
    value=fatalities_air,
    title={"text": "Total Fatalities (Air)"}), row=1, col=1)

fig.add_trace(go.Indicator(
    mode="number",
    value=fatalities_ground,
    title={"text": "Total Fatalities (Ground)"}), row=1, col=2)

fig.add_trace(go.Indicator(
    mode="number",
    value=crashes,
    title={"text": "Total Crashes"}), row=1, col=3)

fig.add_trace(go.Indicator(
    mode="number",
    value=aircrafts,
    title={"text": "Unique Aircrafts"}), row=2, col=1)

fig.add_trace(go.Indicator(
    mode="number",
    value=countries,
    title={"text": "Countries Involved"}), row=2, col=2)

fig.add_trace(go.Indicator(
    mode="number",
    value=aboard_total,
    title={"text": "Total Aboard"}), row=2, col=3)


fig.update_layout(
    height=400,
    width=1000,
    template='presentation',
    paper_bgcolor='rgba(0,0,0,0)',
    plot_bgcolor='rgba(0,0,0,0)',
)

fig.show()

# Save
fig.write_image(os.path.join(results_dir, 'Total_Crashes.jpg'))
fig.write_image(os.path.join(results_dir, 'Total_Crashes.png'))
fig.write_html(os.path.join(results_dir, 'Total_Crashes.html'))

# %% [markdown]
# ## 4. Crashes Over Time
#
# We analyze the number of crashes per year to see trends in aircraft accidents over time.
#
# This helps us identify:
# - Periods with high crash rates (e.g., war or early aviation)
# - Declines in crashes as aviation technology improved

# %%
def classify_operator(op):
    if pd.isna(op) or op.strip().lower() in ['unknown', '', 'nan']:
        return 'Unknown'
    elif 'military' in op.lower() or 'army' in op.lower() or 'navy' in op.lower():
        return 'Military'
    else:
        return 'Commercial'

df['Operator Type'] = df['Operator'].apply(classify_operator)
crashes_by_operator = df.groupby(['Year', 'Operator Type']).size().reset_index(name='Total Crashes')

fig = px.bar(
    crashes_by_operator,
    x='Year',
    y='Total Crashes',
    color='Operator Type',
    title='Crashes Over Time by Operator Type (Military vs Commercial vs Unknown)',
    template='presentation',
    height=600
)

fig.update_layout(
    xaxis=dict(
        title='Year',
        rangeslider=dict(visible=True),
        type='linear'
    ),
    yaxis_title='Total Crashes',
    legend_title='Operator Type'
)
fig.update_layout(template = "presentation",xaxis_title="Year",
                  yaxis_title="Total Crashes",
                  legend_title=dict(text="Operator Type"),
                  xaxis_title_standoff=50,
                  paper_bgcolor = "rgba(0, 0, 0, 0)",
                  plot_bgcolor = "rgba(0, 0, 0, 0)"
                 )
fig.show()

fig.write_image(os.path.join(results_dir, 'Crashes Over Time by Operator Type (Military vs Commercial vs Unknown).jpg'))
fig.write_image(os.path.join(results_dir, 'Crashes Over Time by Operator Type (Military vs Commercial vs Unknown).png'))
fig.write_html(os.path.join(results_dir, 'Crashes Over Time by Operator Type (Military vs Commercial vs Unknown).html'))

# %% [markdown]
# This cell generates a stacked bar chart showing the number of air crashes per year, categorized by `Operator Type` (Military, Unknown, Commercial).
#
# **Data Preparation:**
# - `df_operator_yearly = df.groupby(['Year', 'Operator Type']).size().unstack(fill_value=0).reset_index()`:
#     - Groups the DataFrame by `Year` and `Operator Type`.
#     - `size()`: Counts the number of crashes for each group.
#     - `unstack(fill_value=0)`: Pivots the `Operator Type` to become columns, with crash counts as values. `fill_value=0` ensures that years with no crashes for a specific operator type are filled with 0 instead of NaN.
#     - `reset_index()`: Converts the grouped result back into a DataFrame with `Year` as a regular column.
#
# **Plotly Bar Chart (`px.bar`):**
# - `px.bar(df_operator_yearly, x='Year', y=df_operator_yearly.columns[1:], ...)`:
#     - `x='Year'`: Sets the x-axis to represent the year.
#     - `y=df_operator_yearly.columns[1:]`: Uses all columns from the second onward (i.e., 'Commercial', 'Military', 'Unknown') as the y-values for stacking.
#     - `title`: Sets the chart title.
#     - `labels`: Customizes axis labels for better readability.
#     - `color_discrete_sequence`: Defines the colors for each operator type.
#     - `template='plotly_white'`: Applies a clean white background theme.
#
# **Layout Updates:**
# - `fig.update_layout(...)`: Further customizes the layout.
#     - `barmode='stack'`: Ensures the bars are stacked.
#     - `xaxis_title_standoff`: Adds padding to the x-axis title.
#     - `paper_bgcolor`, `plot_bgcolor`: Sets transparent backgrounds.
#     - `xaxis.rangeslider.visible=True`: Adds a range slider to the x-axis, allowing interactive zooming and panning over the years.
#
# **Interpretation of the Graph:**
# This stacked bar chart illustrates the distribution of air crashes by operator type over time:
# - **Early Aviation (Pre-1940s):** Crashes are relatively few, and the "Unknown" category is quite prominent, likely due to less comprehensive record-keeping or varied definitions of operators. Military crashes also occur, reflecting early military aviation.
# - **World War II Era (1940s-1945):** There's a sharp increase in military aviation crashes, peaking around 1944-1945. This is expected, as military operations significantly increased during this period, leading to more incidents. Commercial crashes remain relatively low during this time.
# - **Post-WWII to Mid-20th Century (1946-1970s):** Commercial aviation crashes begin to rise and eventually surpass military crashes, reflecting the growth of commercial air travel. Military crashes decline significantly after WWII but still occur. The "Unknown" category generally decreases as data collection improves.
# - **Late 20th to Early 21st Century (1980s-Present):** There's a noticeable trend of decreasing total crashes, particularly in commercial aviation, despite the massive increase in air traffic. This suggests significant improvements in aircraft technology, safety regulations, and operational procedures. Military crashes remain at a lower, more consistent level compared to the war era. The "Unknown" category becomes minimal, indicating better data classification.
#
# **Overall Trend:** The graph clearly shows a shift from military-dominated incidents in the early years to commercial aviation, followed by a remarkable overall decline in crashes, highlighting the continuous improvements in aviation safety over the decades.
#
# **Saving the Figure:**
# The graph is saved in JPG, PNG, and HTML formats, making it easy to share and embed.

# %% [markdown]
# ### Exploring Unique Operator Types
#
# To understand the variety of organizations involved in aircraft operations, we use:

# %%
df['Operator'].unique()
# Out:
# array(['Army U.S. - Military', 'Unknown', 'Navy U.S. - JerseyMilitary',
#        ..., 'LATAM', 'SAS Aero', 'Aerotaxi Manaus'], dtype=object)

# %% [markdown]
# ## Top Aircraft Types Involved in Crashes
#
# This plot shows the aircraft models or types that have been involved in the most crashes. By analyzing this, we can identify which aircraft types appear most frequently in crash data, which may indicate their prevalence or highlight safety concerns.
#
# Since there are many aircraft types, we limit the plot to toe t0p 15 most frequent types to keep it readable.

# %% [markdown]
# Identify Top Aircrafts:
#
# top_aircrafts = df['Aircraft'].value_counts().nlargest(10).index:
# df['Aircraft'].value_counts(): Counts the occurrences of each unique aircraft type in the 'Aircraft' column, sorting them in descending order (most frequent first).
# .nlargest(10): Selects the top 10 most frequent aircraft types.
#
# .index: Extracts just the names (indices) of these top 10 aircraft types.
#
# Filter DataFrame:
# top_aircrafts_df = df[df['Aircraft'].isin(top_aircrafts)]: Creates a new DataFrame top_aircrafts_df containing only the rows (crashes) that involve one of the identified top 10 aircraft types.
#
# Aggregate Data:
# agg_data = top_aircrafts_df.groupby('Aircraft').agg(...): Groups the filtered DataFrame by Aircraft type to perform aggregations.
# crash_count=('Aircraft', 'size'): Counts the number of crashes for each aircraft type.
# total_fatalities=('Sum of Fatalities (air)', 'sum'): Sums the 'Sum of Fatalities (air)' for each aircraft type.
# .reset_index(): Converts the grouped result back into a regular DataFrame.
# Plotly Bar Chart Creation (px.bar):
# agg_data.sort_values('crash_count'): Ensures the bars in the chart are sorted by crash_count in ascending order, so the smallest bar is at the bottom and the largest at the top.
# x='crash_count', y='Aircraft': Sets the x-axis to the number of crashes and the y-axis to the aircraft type.
# orientation='h': Creates a horizontal bar chart.
# title='Top 10 Aircraft Types Involved in Crashes with Fatalities': Sets the main title of the chart.
# template='presentation': Applies a clean, presentable Plotly theme.
# height=600: Sets the height of the plot.
# hover_data={'crash_count': True, 'total_fatalities': True}: Configures the information displayed when hovering over a bar, showing both the number of crashes and total fatalities.
# labels: Customizes the axis labels for better readability.
# Layout Updates (fig.update_layout):
# Sets descriptive titles for the x and y axes.
# margin=dict(l=280): Adjusts the left margin to ensure long aircraft names are fully visible.
# xaxis_title_standoff, paper_bgcolor, plot_bgcolor: Further aesthetic adjustments for spacing and transparent backgrounds.
# Save:
# fig.show(): Displays the interactive Plotly figure directly in the notebook output.
# fig.write_image(...) and fig.write_html(...): Saves the figure as static JPG/PNG images and an interactive HTML file to the results_dir.

# %%
top_aircrafts = df['Aircraft'].value_counts().nlargest(10).index
top_aircrafts_df = df[df['Aircraft'].isin(top_aircrafts)]

# Aggregate total crashes and total fatalities per aircraft
agg_data = top_aircrafts_df.groupby('Aircraft').agg(
    crash_count=('Aircraft', 'size'),
    total_fatalities=('Sum of Fatalities (air)', 'sum')
).reset_index()

# plot
fig = px.bar(
    agg_data.sort_values('crash_count'),
    x='crash_count',
    y='Aircraft',
    orientation='h',
    title='Top 10 Aircraft Types Involved in Crashes with Fatalities',
    template='presentation',
    height=600,
    hover_data={
        'crash_count': True,
        'total_fatalities': True
    },
    labels={
        'crash_count': 'Number of Crashes',
        'total_fatalities': 'Total Fatalities'
    }
)

fig.update_layout(
    yaxis_title='Aircraft Type',
    xaxis_title='Number of Crashes',
)
fig.update_layout(
    yaxis_title='Aircraft Type',
    xaxis_title='Number of Crashes',
    margin=dict(l=280) 
)
fig.update_layout(template = "presentation",xaxis_title="Number of Crashes",
                  yaxis_title="Aircraft Type",
                  xaxis_title_standoff=50,
                  paper_bgcolor = "rgba(0, 0, 0, 0)",
                  plot_bgcolor = "rgba(0, 0, 0, 0)"
                 )
fig.show()

fig.write_image(os.path.join(results_dir, 'Top 10 Aircraft Types Involved in Crashes with Fatalities.jpg'))
fig.write_image(os.path.join(results_dir, 'Top 10 Aircraft Types Involved in Crashes with Fatalities.png'))
fig.write_html(os.path.join(results_dir, 'Top 10 Aircraft Types Involved in Crashes with Fatalities.html'))

# %% [markdown]
# This horizontal bar chart vividly illustrates the top 10 aircraft types that have been involved in the most air crashes in the dataset, along with the total fatalities associated with each:
#
# Dominance of Historical Workhorses: The chart clearly shows that the Douglas DC-3 and its military variant, the Douglas C-47, are by far the most frequently crashed aircraft types. This is not necessarily an indictment of their safety design but rather a direct reflection of their unparalleled production numbers and decades of widespread use across both civilian and military aviation globally. They were the "workhorses" of their era, leading to higher exposure to incidents over time.
#
# "Unknown" as a Significant Category: The "Unknown" aircraft type still represents a notable number of crashes, indicating incomplete data for a segment of historical incidents.
#
# Other Legacy Aircraft: The chart includes other aircraft that were highly prevalent in earlier eras, such as the Junkers Ju 52 and various Boeing B-17s, B-29s (primarily military bombers) and B-24s, further emphasizing the historical nature of the dataset.
#
# Modern Jet Involvement: The presence of the Boeing 737 indicates that even highly successful and widely operated modern jetliners will accumulate a certain number of incidents over their long service lives due to sheer flight volume.
#
# Fatalities Correlation: When hovering over the bars, the total_fatalities data will likely show a direct correlation with the crash_count. Aircraft with more crashes generally also have a higher cumulative number of fatalities, which is expected given the high lethality of air crashes.

# %% [markdown]
# ## Aircraft Manufacturers Breakdown
#
# This chart visualizes the distribution of crashes by aircraft manufacturers
# . It helps identify which manufacturers’ planes have been involved in the most incident.
#
# Understanding this breakdown provides insight into industry trends and potential manufacturer-specific safety pattens.

# %% [markdown]
# This cell focuses on the aircraft manufacturers to identify and visualize the top 10 manufacturers whose aircraft have been involved in the highest number of crashes. It also aggregates the total fatalities associated with these manufacturers, providing a dual perspective of crash frequency and severity.

# %%
top_makers = df['Aircraft Manufacturer'].value_counts().nlargest(10).index

top_makers_df = df[df['Aircraft Manufacturer'].isin(top_makers)]
agg_manufacturer = top_makers_df.groupby('Aircraft Manufacturer').agg(
    crash_count=('Aircraft Manufacturer', 'size'),
    total_fatalities=('Sum of Fatalities (air)', 'sum')
).reset_index()


fig = px.bar(
    agg_manufacturer.sort_values('crash_count'),
    x='crash_count',
    y='Aircraft Manufacturer',
    orientation='h',
    title='Top 10 Aircraft Manufacturers by Number of Crashes',
    template='presentation',
    height=600,
    hover_data={
        'crash_count': True,
        'total_fatalities': True
    },
    labels={
        'crash_count': 'Number of Crashes',
        'total_fatalities': 'Total Fatalities',
        'Aircraft Manufacturer': 'Manufacturer'
    }
)


fig.update_layout(
    yaxis_title='Manufacturer',
    xaxis_title='Number of Crashes',
    margin=dict(l=220) 
)
fig.update_layout(template = "presentation",xaxis_title="Number of Crashes",
                  yaxis_title="Manufacturer",
                  xaxis_title_standoff=50,
                  paper_bgcolor = "rgba(0, 0, 0, 0)",
                  plot_bgcolor = "rgba(0, 0, 0, 0)"
                 )
fig.show()

fig.write_image(os.path.join(results_dir, 'Top 10 Aircraft Manufacturers by Number of Crashes.jpg'))
fig.write_image(os.path.join(results_dir, 'Top 10 Aircraft Manufacturers by Number of Crashes.png'))
fig.write_html(os.path.join(results_dir, 'Top 10 Aircraft Manufacturers by Number of Crashes.html'))

# %% [markdown]
# This horizontal bar chart visually presents the top 10 aircraft manufacturers ranked by the number of crashes their aircraft have been involved in:
# "Douglas" Manufacturer Dominance: The most striking feature is the overwhelming number of crashes categorized under "Douglas". With 995 crashes, this category significantly dwarfs all other identified manufacturers.
# Douglas Manufacturers Lead Among Identified Entries: Among the identified manufacturers, Douglas leads with 995 crashes, followed by Boeing with 407 crashes. These high numbers are primarily a consequence of their historical dominance and prolific production. Both companies have manufactured vast numbers of aircraft over many decades, including during periods of less stringent safety regulations.

# %% [markdown]
# ## Fatalities vs Aircraft Types (Top 10 by Fatalities)
#
# This bar chart highlights the top 10 aircraft types that have caused the highest number of fatalities in crashes.
#
# By focusing on fatality counts rather than just crash counts, we better understand which aircraft models have been involved in the deadliest incidents.

# %%
fatalities_by_aircraft = df.groupby('Aircraft').agg(
    total_fatalities=('Sum of Fatalities (air)', 'sum'),
    crash_count=('Aircraft', 'size')
).reset_index()


top_fatal_aircraft = fatalities_by_aircraft.nlargest(10, 'total_fatalities')


fig = px.bar(
    top_fatal_aircraft.sort_values('total_fatalities'),
    x='total_fatalities',
    y='Aircraft',
    orientation='h',
    title='Top 10 Aircraft Types by Total Fatalities',
    template='presentation',
    height=600,
    hover_data={
        'crash_count': True,
        'total_fatalities': True
    },
    labels={
        'total_fatalities': 'Total Fatalities',
        'crash_count': 'Number of Crashes',
        'Aircraft': 'Aircraft Type'
    }
)


fig.update_layout(
    yaxis_title='Aircraft Type',
    xaxis_title='Total Fatalities',
    margin=dict(l=280)
)
fig.update_layout(template = "presentation",xaxis_title="Total Fatalities",
                  yaxis_title="Aircraft Type",
                  xaxis_title_standoff=50,
                  paper_bgcolor = "rgba(0, 0, 0, 0)",
                  plot_bgcolor = "rgba(0, 0, 0, 0)"
                 )
fig.show()
fig.write_image(os.path.join(results_dir, 'Top 10 Aircraft Types by Total Fatalities.jpg'))
fig.write_image(os.path.join(results_dir, 'Top 10 Aircraft Types by Total Fatalities.png'))
fig.write_html(os.path.join(results_dir, 'Top 10 Aircraft Types by Total Fatalities.html'))

# %% [markdown]
# This plot shows that Boeing B 727 and Boeing B 727 have the highest number of crashes among identified manufacturers, largely due to their long history and vast production. A significant portion of crashes are also attributed to an "Unknown" manufacturer, highlighting data gaps.

# %% [markdown]
# ### Map of crash locations

# %%
import json

# Load the cached geocoding from notebooks folder
with open('geocoded_locations.json', 'r') as f:
    location_coords = json.load(f)

df['Latitude'] = df['Location'].map(lambda x: location_coords.get(x, {}).get('lat'))
df['Longitude'] = df['Location'].map(lambda x: location_coords.get(x, {}).get('lon'))
df['Geo Status'] = df['Latitude'].apply(lambda x: 'Unknown' if pd.isna(x) else 'Geocoded')

df['Geo Status'] = df['Latitude'].apply(lambda x: 'Unknown' if pd.isna(x) else 'Geocoded')
df['Geo Status'].value_counts()
# Out:
# Geo Status
# Geocoded    2795
# Unknown     2235
# Name: count, dtype: int64

# %% [markdown]
# ## Map of Crash Locations
# This interactive map shows the geographical locations of aircraft crashes worldwide.

# %%
map_df = df.dropna(subset=['Latitude', 'Longitude'])

fig = px.scatter_geo(
    map_df,
    lat='Latitude',
    lon='Longitude',
    hover_name='Aircraft',
    hover_data={
        'Year': True,
        'Operator': True,
        'Sum of Fatalities (air)': True
    },
    color='Sum of Fatalities (air)',
    size='Sum of Fatalities (air)',
    projection='natural earth',
    title='Aircrash Locations with Fatalities',
    template='presentation',
    height=700
)

fig.update_layout(
    paper_bgcolor="rgba(0,0,0,0)",
    plot_bgcolor="rgba(0,0,0,0)",
    geo=dict(
        bgcolor='rgba(0,0,0,0)'
    ),
    title_font=dict(size=20),
    margin=dict(l=0, r=0, t=50, b=0)
)
fig.show()
fig.write_image(os.path.join(results_dir, 'Aircrash Locations with Fatalities.jpg'))
fig.write_image(os.path.join(results_dir, 'Aircrash Locations with Fatalities.png'))
fig.write_html(os.path.join(results_dir, 'Aircrash Locations with Fatalities.html'))

# %% [markdown]
# global map shows air crash locations. The size and color of each point indicate the number of fatalities, with larger, brighter points representing more severe crashes. North America and Europe show a high density of incidents.

# %% [markdown]
# ## Crashes by Continent or Region
#
# This plot breaks down the number of crashes across different continents or regions.
#
# It provides a high-level view of where most crashes occur, which may relate to factors like air traffic volume, infrastructure, or regional safety regulations.

# %%
import pycountry_convert as pc
import pycountry

def get_continent(country_name):
    try:

        if country_name.lower() == 'united states':
            country_name = 'United States of America'
        if country_name.lower() == 'uk':
            country_name = 'United Kingdom'

        country_code = pycountry.countries.lookup(country_name).alpha_2
        continent_code = pc.country_alpha2_to_continent_code(country_code)

        continent_name = {
            'NA': 'North America',
            'SA': 'South America',
            'AS': 'Asia',
            'AF': 'Africa',
            'OC': 'Oceania',
            'EU': 'Europe',
            'AN': 'Antarctica'
        }[continent_code]

        return continent_name
    except:
        return 'Unknown'

# %%
df['Continent'] = df['Country/Region'].apply(get_continent)

# %%
# plot
import plotly.express as px

continent_counts = df['Continent'].value_counts().reset_index()
continent_counts.columns = ['Continent', 'Crash Count']

fig = px.bar(
    continent_counts,
    x='Crash Count',
    y='Continent',
    orientation='h',
    title='Number of Crashes by Continent',
    template='presentation',

    height=500
)

fig.update_layout(
    margin=dict(l=180)
)

fig.update_layout(template = "presentation",xaxis_title="Number of Crashes",
                  yaxis_title="Continent",
                  xaxis_title_standoff=50,
                  paper_bgcolor = "rgba(0, 0, 0, 0)",
                  plot_bgcolor = "rgba(0, 0, 0, 0)"
                 )
fig.show()
fig.write_image(os.path.join(results_dir, 'Number of Crashes by Continent.jpg'))
fig.write_image(os.path.join(results_dir, 'Number of Crashes by Continent.png'))
fig.write_html(os.path.join(results_dir, 'Number of Crashes by Continent.html'))

# %% [markdown]
# ### Heatmap of Aircrashes per Country

# %%
# Group by country and count crashes
crash_counts = df.groupby('Country/Region').size().reset_index(name='Crashes')

# Choropleth heatmap
fig = px.choropleth(
    crash_counts,
    locations='Country/Region',
    locationmode='country names',
    color='Crashes',
    color_continuous_scale='Reds',
    title='Heatmap of Aircrashes per Country',
    template='presentation',
)

fig.update_layout(
    paper_bgcolor="rgba(0,0,0,0)",
    plot_bgcolor="rgba(0,0,0,0)",
    geo=dict(
        bgcolor='rgba(0,0,0,0)'
    ),
    title_font=dict(size=20),
    margin=dict(l=0, r=0, t=50, b=0)
)
fig.show()
fig.write_image(os.path.join(results_dir, 'Heatmap of Aircrashes per Country.jpg'))
fig.write_image(os.path.join(results_dir, 'Heatmap of Aircrashes per Country.png'))
fig.write_html(os.path.join(results_dir, 'Heatmap of Aircrashes per Country.html'))

# %% [markdown]
# ## Fatalities by Continent
#
# This chart shows the total fatalities caused by crashes within each continent.
#
# It highlights regions with the deadliest crashes and can be compared with crash counts to analyze severity differences.

# %%
fatalities_by_continent = df.groupby('Continent')['Sum of Fatalities (air)'].sum().reset_index()
fatalities_by_continent.columns = ['Continent', 'Total Fatalities']
fatalities_by_continent = fatalities_by_continent.sort_values('Total Fatalities', ascending=False)

# %%
import plotly.express as px

fig = px.bar(
    fatalities_by_continent,
    x='Total Fatalities',
    y='Continent',
    orientation='h',
    title='Total Fatalities by Continent',
    template='presentation',
     color_discrete_sequence= px.colors.sequential.RdBu,
    height=500
)

fig.update_layout(
    margin=dict(l=190)
)

fig.update_layout(template = "presentation",xaxis_title="Total Fatalities",
                  yaxis_title="Continent",
                  xaxis_title_standoff=50,
                  paper_bgcolor = "rgba(0, 0, 0, 0)",
                  plot_bgcolor = "rgba(0, 0, 0, 0)"
                 )
fig.show()
fig.write_image(os.path.join(results_dir, 'Total Fatalities by Continent.jpg'))
fig.write_image(os.path.join(results_dir, 'Total Fatalities by Continent.png'))
fig.write_html(os.path.join(results_dir, 'Total Fatalities by Continent.html'))

# %% [markdown]
# ## Crashes by Operator Type
#
# This bar chart compares the number of crashes involving military, commercial, and unknown operators.
#
# It helps understand how crash frequencies vary across these operator categories.

# %%
operator_counts = df['Operator Type'].value_counts().reset_index()
operator_counts.columns = ['Operator Type', 'Crash Count']

fig = px.bar(
    operator_counts,
    x='Crash Count',
    y='Operator Type',
    orientation='h',
    title='Crashes by Operator Type',
    template='presentation',
    color='Operator Type',
    color_discrete_map={
        'Military': 'indianred',
        'Commercial': 'royalblue',
        'Unknown': 'gray'
    },
    height=400
)

fig.update_layout(
    margin=dict(l=150)
)

fig.update_layout(template = "presentation",xaxis_title="Number of Crashes",
                  yaxis_title="Operator Type",
                  xaxis_title_standoff=50,
                  paper_bgcolor = "rgba(0, 0, 0, 0)",
                  plot_bgcolor = "rgba(0, 0, 0, 0)"
                 )
fig.show()
fig.write_image(os.path.join(results_dir, 'Crashes by Operator Type.jpg'))
fig.write_image(os.path.join(results_dir, 'Crashes by Operator Type.png'))
fig.write_html(os.path.join(results_dir, 'Crashes by Operator Type.html'))

# %% [markdown]
# ## Fatalities per Operator Type
#
# Here, we analyze fatalities associated with each operator category.
#
# This reveals which operator types are linked to more severe crash outcomes.

# %%
fatalities_by_operator = df.groupby('Operator Type')['Sum of Fatalities (air)'].sum().reset_index()
fatalities_by_operator.columns = ['Operator Type', 'Total Fatalities']
fatalities_by_operator = fatalities_by_operator.sort_values('Total Fatalities', ascending=False)

fig = px.bar(
    fatalities_by_operator,
    x='Total Fatalities',
    y='Operator Type',
    orientation='h',
    title='Total Fatalities by Operator Type',
    template='presentation',
    color='Operator Type',
    color_discrete_map={
        'Military': 'indianred',
        'Commercial': 'royalblue',
        'Unknown': 'gray'
    },
    height=400
)

fig.update_layout(
    margin=dict(l=150)
)

fig.update_layout(template = "presentation",xaxis_title="Total Fatalities",
                  yaxis_title="Operator Type",
                  xaxis_title_standoff=50,
                  legend_title=dict(text="Operator Type"),
                  paper_bgcolor = "rgba(0, 0, 0, 0)",
                  plot_bgcolor = "rgba(0, 0, 0, 0)"
                 )
fig.show()
fig.write_image(os.path.join(results_dir, 'Total Fatalities by Operator Type.jpg'))
fig.write_image(os.path.join(results_dir, 'Total Fatalities by Operator Type.png'))
fig.write_html(os.path.join(results_dir, 'Total Fatalities by Operator Type.html'))

# %% [markdown]
# ## Crashes Involving Ground Deaths
#
# Some crashes cause fatalities on the ground, which are rare but particularly tragic.
#
# This visualization highlights incidents where ground deaths occurred and helps understand their frequency and severity.

# %%
crashes_with_ground_deaths = df[df['Sum of Ground'] > 0].copy()
total_ground_deaths = df['Sum of Ground'].sum()
total_air_deaths = df['Sum of Fatalities (air)'].sum()


top_ground_deaths = crashes_with_ground_deaths.sort_values('Sum of Ground', ascending=False).head(10)

fig = px.bar(
    top_ground_deaths,
    x='Sum of Ground',
    y='Location',
    orientation='h',
    title='Top 10 Crashes with Most Ground Fatalities',
    template='presentation',
    hover_data={
        'Year': True,
        'Aircraft': True,
        'Operator': True,
        'Sum of Fatalities (air)': True,
        'Sum of Aboard': True
    },
    height=500
)

fig.update_layout(
    margin=dict(l=280)
)

fig.update_layout(template = "presentation",xaxis_title="Ground Fatalities",
                  yaxis_title="Crash Location",
                  xaxis_title_standoff=50,
                    paper_bgcolor = "rgba(0, 0, 0, 0)",
                  plot_bgcolor = "rgba(0, 0, 0, 0)"
                 )
fig.show()
fig.write_image(os.path.join(results_dir, 'Top 10 Crashes with Most Ground Fatalities.jpg'))
fig.write_image(os.path.join(results_dir, 'Top 10 Crashes with Most Ground Fatalities.png'))
fig.write_html(os.path.join(results_dir, 'Top 10 Crashes with Most Ground Fatalities.html'))

# %% [markdown]
# ## Most Deadly Incidents
#
# This chart lists the crashes with the highest total fatalities (airborne plus ground deaths).
#
# It provides a focused view on the worst air disasters and can help identify common factors in these extreme cases.

# %%
df['Total Fatalities'] = df['Sum of Fatalities (air)'] + df['Sum of Ground']
top_deadly_crashes = df.sort_values('Total Fatalities', ascending=False).head(10)

# %%
import plotly.express as px

fig = px.bar(
    top_deadly_crashes,
    x='Total Fatalities',
    y='Location',
    orientation='h',
    title='Top 10 Most Deadly Aircrash Incidents',
    template='presentation',
    hover_data={
        'Year': True,
        'Aircraft': True,
        'Operator': True,
        'Sum of Fatalities (air)': True,
        'Sum of Ground': True,
        'Sum of Aboard': True
    },
    height=600
)

fig.update_layout(
    margin=dict(l=290)
)

fig.update_layout(template = "presentation",xaxis_title="Total Fatalities (Air + Ground)",
                  yaxis_title="Crash Location",
                  xaxis_title_standoff=50,
                    paper_bgcolor = "rgba(0, 0, 0, 0)",
                  plot_bgcolor = "rgba(0, 0, 0, 0)"
                 )
fig.show()
fig.write_image(os.path.join(results_dir, 'Top 10 Most Deadly Aircrash Incidents.jpg'))
fig.write_image(os.path.join(results_dir, 'Top 10 Most Deadly Aircrash Incidents.png'))
fig.write_html(os.path.join(results_dir, 'Top 10 Most Deadly Aircrash Incidents.html'))

# %% [markdown]
# ## 6. Survival Rate
#
# Understanding the survival rate is another critical aspect of air crash analysis. This metric highlights the effectiveness of safety measures and emergency procedures.
# ss.

# %%
df['Survivors'] = df['Sum of Aboard'] - df['Sum of Fatalities (air)']
df['Survival Rate (%)'] = (df['Survivors'] / df['Sum of Aboard']) * 100
df = df[df['Sum of Aboard'] > 0]

# %% [markdown]
# This cells we started by Summing the column called Sum of Aboard(people who were in plane) and also we find Sum for column called Sum Sum of Fatalities (air) people who dead in plane, so after haviing people who were in Plane and who dead in plane we can find people who surviced in that Aircrash

# %%
total_aboard = df['Sum of Aboard'].sum()
total_fatalities = df['Sum of Fatalities (air)'].sum()
total_survivors = total_aboard - total_fatalities

# %%
# Group by Year and sum survivors and fatalities
yearly_stats = df.groupby('Year').agg({
    'Survivors': 'sum',
    'Sum of Fatalities (air)': 'sum'
}).reset_index()

fig = go.Figure()

fig.add_trace(go.Bar(
    x=yearly_stats['Year'],
    y=yearly_stats['Survivors'],
    name='Survived',
    marker_color='green'
))

fig.add_trace(go.Bar(
    x=yearly_stats['Year'],
    y=yearly_stats['Sum of Fatalities (air)'],
    name='Fatalities',
    marker_color='red'
))

fig.update_layout(
    barmode='stack',
    title='Survivors vs Fatalities by Year',
    xaxis_title='Year',
    yaxis_title='Number of People',
    template='presentation',
    height=500
)
fig.update_layout(
    xaxis=dict(
        title='Year',
        rangeslider=dict(visible=True),
        type='linear'
    ),
    yaxis_title='Number of People',
    legend_title='People'
)
fig.update_layout(template = "presentation",xaxis_title="Year",
                  yaxis_title="Number of People",
                  xaxis_title_standoff=50,
                  legend_title=dict(text="People"),
                  paper_bgcolor = "rgba(0, 0, 0, 0)",
                  plot_bgcolor = "rgba(0, 0, 0, 0)"
                 )
fig.show()
fig.write_image(os.path.join(results_dir, 'Survivors vs Fatalities by Year.jpg'))
fig.write_image(os.path.join(results_dir, 'Survivors vs Fatalities by Year.png'))
fig.write_html(os.path.join(results_dir, 'Survivors vs Fatalities by Year.html'))

# %%
df = df.fillna('Unknown')
df.isna().sum()
# Out:
# Year                       0
# Quarter                    0
# Month                      0
# Day                        0
# Country/Region             0
# Aircraft Manufacturer      0
# Aircraft                   0
# Location                   0
# Operator                   0
# Sum of Ground              0
# Sum of Fatalities (air)    0
# Sum of Aboard              0
# Month_num                  0
# Date                       0
# Operator Type              0
# Latitude                   0
# Longitude                  0
# Geo Status                 0
# Continent                  0
# Total Fatalities           0
# Survivors                  0
# Survival Rate (%)          0
# dtype: int64

# %% [markdown]
# ## Total Fatalities by Month
#
# This chart illustrates the total number of air crash fatalities occurring in each month across the full dataset (1908–2023). A clear seasonal pattern is observed:

# %%
month_order = [
    "January", "February", "March", "April", "May", "June",
    "July", "August", "September", "October", "November", "December"
]
monthly_fatalities = (
    df.groupby("Month")["Sum of Fatalities (air)"]
    .sum()
    .reindex(month_order)
    .reset_index()
    .rename(columns={"Sum of Fatalities (air)": "Total Fatalities"})
)

# Plot
fig = px.bar(
    monthly_fatalities,
    x="Month",
    y="Total Fatalities",
    category_orders={"Month": month_order},
    title="Total Fatalities by Month (1908–2023)",
    labels={"Month": "Month", "Total Fatalities": "Number of Fatalities"},
    color="Total Fatalities",
    color_discrete_sequence= ["#5D3FD3"]
)

fig.update_layout(xaxis_tickangle=-45)
fig.update_layout(template = "presentation",xaxis_title="Total Fatalities by Month (1908–2023)",
                  yaxis_title="Total Fatalities",
                  xaxis_title_standoff=50,
                    paper_bgcolor = "rgba(0, 0, 0, 0)",
                  plot_bgcolor = "rgba(0, 0, 0, 0)"
                 )
fig.show()
fig.write_image(os.path.join(results_dir, 'Total Fatalities by Month (1908–2023).jpg'))
fig.write_image(os.path.join(results_dir, 'Total Fatalities by Month (1908–2023).png'))
fig.write_html(os.path.join(results_dir, 'Total Fatalities by Month (1908–2023).html'))

# %% [markdown]
# - **July and August** record the highest fatalities, likely linked to peak travel periods in the northern hemisphere’s summer.
# - **December and January** also show elevated counts, possibly due to holiday travel and adverse winter conditions.
# - **February** consistently shows the lowest number of fatalities, which may be due to it being the shortest month with typically lower air traffic.
#
# These trends suggest that seasonal flight volume and weather conditions may influence the frequency and severity of air incidents.

# %%
# import ipywidgets as widgets
# from IPython.display import display

# df.loc[:, 'Year'] = pd.to_numeric(df['Year'], errors='coerce')
# df = df.dropna(subset=['Year']) 
# df['Year'] = df['Year'].astype(int)


# # Year slider (range)
# year_slider = widgets.IntRangeSlider(
#     value=[df['Year'].min(), df['Year'].max()],
#     min=df['Year'].min(),
#     max=df['Year'].max(),
#     step=1,
#     description='Year Range:',
#     continuous_update=False,
#     layout=widgets.Layout(width='80%')
# )
# # Region dropdown (multi-select)
# region_dropdown = widgets.SelectMultiple(
#     options=sorted(df['Location'].unique()),
#     value=tuple(sorted(df['Location'].unique())),  # default all selected
#     description='Region',
#     disabled=False,
#     layout=widgets.Layout(width='50%')
# )

# # Aircraft dropdown (multi-select)
# aircraft_dropdown = widgets.SelectMultiple(
#     options=sorted(df['Aircraft'].unique()),
#     value=tuple(sorted(df['Aircraft'].unique())),  # default all selected
#     description='Aircraft',
#     disabled=False,
#     layout=widgets.Layout(width='50%')
# )

# def update_plot(year_range, regions, aircrafts):
#     # Filter dataframe based on widget selections
#     filtered_df = df[
#         (df['Year'] >= year_range[0]) & (df['Year'] <= year_range[1]) &
#         (df['Location'].isin(regions)) &
#         (df['Aircraft'].isin(aircrafts))
#     ]
    
# out = widgets.interactive_output(
#     update_plot,
#     {
#         'year_range': year_slider,
#         'regions': region_dropdown,
#         'aircrafts': aircraft_dropdown
#     }
# )

# display(year_slider, region_dropdown, aircraft_dropdown, out)

# %%
df
# Out:
#       Year Quarter      Month  Day  Country/Region Aircraft Manufacturer  \
# 0     1908   Qtr 3  September   17   United States                Wright
# 1     1909   Qtr 3  September    7          France                Wright
# 2     1912   Qtr 3       July   12         Unknown               Unknown
# 3     1913   Qtr 3     August    6  United Kingdom               Curtiss
# 4     1913   Qtr 3  September    9         Unknown              Zeppelin
# ...    ...     ...        ...  ...             ...                   ...
# 5025  2022   Qtr 4   November    6         Unknown                   ATR
# 5026  2022   Qtr 4   November   18         Unknown                Airbus
# 5027  2022   Qtr 4   November   21         Unknown                 Piper
# 5028  2023   Qtr 1    January   15         Unknown                   ATR
# 5029  2023   Qtr 3  September   16          Brazil               Embraer
#
#                              Aircraft  \
# 0                    Wright Flyer III
# ...

# %%
# output_file = os.path.join(processed_dir, 'final_cleaned_data.csv')
# df.to_csv(output_file, index=False)
# print(f"CSV file saved to: {output_file}")

# %%
# import re
# df = {
#     'Location': [
#         'virginia', 'france', 'atlantic', 'victoria british', 'over the north sea',
#         'military - german navy', 'near johannisthal germany', 'tienen belgium',
#         'off cuxhaven germany', 'near jambol bulgeria', 'billericay england',
#         'potters bar england', 'mainz germany', 'off west hartlepool england',
#         'near gent belgium', 'off northern germany', 'military - german navy',
#         'near texel island north', 'off vlieland island north',
#         'near yarmouth england?', 'off western denmark', 'military - german navy',
#         'near luneville france', 'over the mediterranean', 'military - german navy',
#         'off helgoland island germany', 'ameland island north', 'elizabeth new',
#         'cleveland ohio', 'dix run pennsylvania', 'verona italy', 'newcastle england',
#         'cantonsville maryland', 'long valley new', 'catherham surrey',
#         'new paris indian', 'newark new', 'newark new', 'heller field new',
#         'oskaloosa iowa', 'cleveland ohio', 'cartagena colombia', 'bedford england',
#         'college park maryland', 'morristown new', 'pemberville ohio',
#         'hillersburg pennsylvania', 'off port vendres france', 'valencia spain',
#         'batavia illinois', 'tie siding wyoming', 'london england', 'barcelona spain',
#         'mendotta minnisota', 'la crosse wisconsin', 'off gibraltar', 'aeropostale',
#         'elko nevada', 'point cook australia', 'mitchel field ny', 'us',
#         'cleveland ohio', 'rock springs wyoming', 'toulouse france',
#         'river humber england', 'paris france', 'near murchinson river australia',
#         'paris france', 'near norfolk virginia', 'north atlantic ocean',
#         'aero limited', 'grandvilliers france', 'pao ting fou china?',
#         'off folkestone kent', 'fuhlsbuttel germany?', 'near saverne lorraine',
#         'cadix spain', 'indianapolis indian', 'venice italy', 'delarache morocco',
#         'fez morocco', 'ajaccio france', 'barcelona spain', 'cheyenne wyoming',
#         'meadville pennsylvania', 'near amiens picrdie', 'bucharest romania',
#         'east mallling united', 'colton ohio', 'near ivinghoe buckinghamshire',
#         'russia', 'cccp', 'castalia ohio', 'over the mediterranean sea',
#         'military - french navy', 'egbert wy', 'us', 'grampian pennsylvania',
#         'over the english channel', 'klm royal dutch airlines',
#         'barranquilla colombia', 'united states', 'us aerial mail service',
#         'cabrerolles france', 'goshen indiana', 'purley england', 'near tiflis georgia',
#         'alicante spain', 'landrécies france', 'alicante spain', 'rosas spain',
#         'budapest hungary', 'caldwell ohio', 'mt. nittany ohio',
#         'off boulogne-sur-mer france', 'nouadhibou mauritania', 'montpelier ohio',
#         'staaken germany', 'english channel', 'air union', 'rossaugpt czechoslovakia',
#         'wolvertem belgium', 'juist germany', 'hurst kent', 'new york new',
#         'leigh kent', 'bueren germany', 'english channel', 'imperial airways',
#         'cape bojador morocco', 'medford oregon', 'rabat morocco', 'tambo qld',
#         'king hill idaho', 'floh germany', 'goshen indiana', 'algiers algeria',
#         'amoneburg germany', 'sevenoaks england', 'willington connecticut',
#         'atlantic ocean', 'private', 'hadley news', 'schleiz germany',
#         'thies mauritania', 'new brunswick new', 'strasburg france',
#         'over the gulf of finland', 'aero o-y', 'corunna indiana', 'almeria spain',
#         'near marseille airlines', 'near canajoharie news', 'solis uruguay',
#         'l\'hospitalet ariège', 'tarragona spain', 'almeria spain',
#         'marquette nebraska', 'off cape griz nez france', 'federal wyoming',
#         'minuesa spain', 'florianopolis brazil', 'florianopolis',
#         'dearborn minnesota', 'radevormwald germany', 'frankfurt germany',
#         'lebo kansas', 'over the gulf of finland', 'aero o-y', 'purley england',
#         'waalhaven netherlands', 'near port townsend bc', 'toul france',
#         'adelaide hills australia', 'pocatello idaho', 'heroldbach germany',
#         'gerona spain', 'polk pennsylvania', 'valence france', 'off gibraltar',
#         'aeropostale', 'edgerton ohio', 'bristolville ohio', 'edgerton ohio',
#         'spur texas', 'near rio de janeiro condors', 'spokan washington',
#         'letzlingen germany', 'huron ohio', 'chattanooga tennessee', 'reims france',
#         'stafford springs connecticut', 'cove oregon', 'near corfu greece',
#         'off morocco', 'aeropostale', 'morgantown west', 'newark new',
#         'near beaumont california', 'san diego california', 'tampico mexico', 'tököl',
#         'algiers', 'aeropostale', 'santiago de cuba cuba', 'barcelona spain',
#         'off dungeness england', 'st. paul minnesota', 'near lindau bavaria',
#         'columbus ohio', 'clovis new', 'elm germany', 'sochi russia',
#         'needles california', 'mt. taylor near', 'jask iran', 'north atlantic ocean',
#         'aeropostale', 'saint catharines ontario', 'jacumba california',
#         'mt lamentation connecticut', 'off larache morocco', 'off spezia italy',
#         'mount vernon ohio', 'off bremerton washington', 'cerro del carbon mexico',
#         'near godstone surrey', 'off corsica france', 'terranova pausania east',
#         'vancouver washington', 'chagrin falls ohio', 'near berlin germany',
#         'amarillo texas', 'off venice california?', 'brawnson nebraska',
#         'antananarivo madagascar', 'oceanside california', 'off ceuta spain',
#         'kansas city missouri', 'hartford connecticut', 'marden england',
#         'jersey city new', 'buenos aires argentina', 'boston massachusetts',
#         'bornholm denmark', 'arkansas pass texas', 'near meopham kent',
#         'iglau czechoslovakia', 'croydon england', 'edmonton alberta',
#         'near beauvais france', 'dresden germany', 'la rache morocco',
#         'perth australia', 'prince rupert bc', 'near neufchatel france',
#         'brookston indiana', 'off of santos brazil', 'techachapi mountains california',
#         'shanghai china', 'melle belgium', 'bluff mountain washington',
#         'wairoa new', 'bagot manitoba', 'off spain', 'aeropostale',
#         'new south wales australia', 'bazaar kansas', 'near letschen germany',
#         'burbank california', 'wampit australia', 'bellefonte pennsylvania',
#         'near sandoway burma', 'walbridge ohio', 'saarbrucken germany',
#         'chicago illinois', 'temora australia', 'centralia illinois',
#         'kurudjevo bulgaria', 'cincinnati ohio', 'chicago illinois',
#         'near craiova oltenia', 'oakland california', 'novia scotia canada',
#         'brazil', 'syndicato condor', 'camden new', 'sir lowry\'s pass south',
#         'salt lake city utah', 'near tsinan china', 'pasco washington',
#         'kewanee illinois', 'bangkok thailand', 'off algiers', 'aeropostale',
#         'springfield ohio', 'colvin park ilinois', 'lebec california',
#         'off miami florida', 'rio vista california', 'marcellus michigan',
#         'off setiba brazil', 'saint louis illinois', 'calimesa california',
#         'steubenville ohio', 'rutbah wells iraq', 'bedford ohio',
#         'fort wayne indiana', 'burbank california', 'portland oregon',
#         'mount el plomo near', 'beyrouth lebanon', 'tubergen germany',
#         'salt flats texas', 'selsdon park england', 'byron bay australia',
#         'port etienne mauritania', 'villa monte bolivia', 'ramsgate england',
#         'echterpfuhl germany', 'marianna arkansas', 'rocky ridge colorado',
#         'amarillo texas', 'wau australia', 'algiers', 'aeropostale',
#         'newark new', 'marietta georgia', 'bourne texas', 'eugene oregon',
#         'near mendoza argentina', 'hayward california', 'near dixmude belgium',
#         'hemkenrode germany', 'off barnegat new', 'near castrovillari calabria',
#         'traunstein germany', 'near viladrau spain', 'bowling green virginia',
#         'glenview illinois', 'aegean sea', 'societa anonima aero expresso italiana',
#         'quay new', 'near ljubljana yugoslavia', 'chesterton indiana',
#         'etobon france', 'portland oregon', 'moriarty new', 'near tsinan china',
#         'near kharkov ukraine', 'wedron illinois', 'hamburg germany',
#         'eshowe south', 'near ruysselede belgium', 'corbigny france',
#         'carombe france', 'near salt lake city utah', 'rio de oro morocco',
#         'petersburg illinois', 'pereira colombia', 'near lima peru',
#         'ningpo bay china', 'english channel', 'air france', 'croydon england',
#         'mongaup mountain new', 'junin argentina', 'chausseehausen germany',
#         'burbank california', 'san bernardino california', 'near tuttlingen germany',
#         'bahia brazil', 'amazonia missouri', 'english channel', 'hillman\'s airways',
#         'near winton australia', 'bass strait australia', 'kiapit australia',
#         'near longreach australia', 'amazonia montana', 'salchau germany',
#         'columbia missouri', 'palma soriano cuba', 'rutbah wells syria',
#         'sunbright tennessee?', 'aeroflot', 'near karachi pakistan',
#         'pittsburgh pennsylvania', 'stettin germany', 'off point sur california',
#         'schievelbein germany', 'el arish egypt', 'off samland germany',
#         'beauvais france', 'brilon germany', 'near walsenberg colorado',
#         'atlanta missouri', 'flint michigan', 'near moscow russia',
#         'glendo wyoming', 'maywood illinois', 'san barbra honduras?',
#         'medellin colombia', 'amsterdam netherlands',
#         'off chandeleur island mississippi', 'pian giacomo switzerland',
#         'cardiff united', 'el retiro colombia', 'cairo egypt', 'near gilmer texas',
#         'walakpa near', 'near glendo wyoming', 'burbank california',
#         'near tambo panama', 'off finders island victoria',
#         'near cheyenne wyoming', 'gulf of finland', 'aero o-y', 'troy new',
#         'cheyenne wyoming', 'off nhambupe brazil', 'brindisi italy',
#         'near fort worth texas', 'istres france', 'tours france',
#         'croydon england', 'wroctaw poland', 'off alexandria egypt',
#         'goodwin arkansas', 'tres esquinas colombia', 'near cordillera boliva',
#         'off ajaccio corsica', 'denton texas', 'atlantic ocean', 'air france',
#         'south atlantic ocean', 'deutsche lufthansa', 'near tengya china',
#         'ovalle chile', 'amemeca mexico', 'pavillon new',
#         'uniontown pennsylvania', 'port of spain trinidad', 'near turin italy',
#         'orvin switzerland', 'senlis france', 'basel switzerland',
#         'mount waverley australia', 'malmo sweden', 'hannover germany',
#         'mt. lihesten norway', 'zagreb croatia', 'kulyab tajikistan',
#         'off channel islands jersey', 'mazamet france', 'ciudad serdan',
#         'st. louis missouri', 'choco colombia', 'altenkirchen germany',
#         'mirabella greece', 'near pittsburgh pennsylvania', 'benghazi libya',
#         'english channel', 'imperial airways', 'walsenberg colorado',
#         'napierville illinois', 'francisco rueda', 'selby north',
#         'near tabarz germany', 'nurnberg germany', 'london england',
#         'near grenoble france', 'near moscow russia', 'off dakar french',
#         'croydon england', 'near salt lake city utah', 'kellogg idaho',
#         'near milford pennsylvania', 'near dallas texas', 'newhall california',
#         'near playa v icente veracruz', 'near newhall california', 'oran algeria',
#         'off san francisco california', 'mcpherson ranges queensland',
#         'bathurst gambia', 'near ouroux france', 'clifton pennsylvania',
#         'wetnum germany', 'lakehurst new', 'stuttgart germany',
#         'desertores island región de los los lagos', 'fuerzs aerea de chile?',
#         'enta', 'off lae new', 'hal belgium', 'off cristobal panama',
#         'wadi halfa sudan', 'bistrita romania', 'chilang point bias',
#         'daytona beach florida', 'san luis argentina', 'wau papua',
#         'phaleron bay greece', 'palembang netherlands', 'haydens peak wyoming',
#         'off western africa', 'air france', 'warsaw poland', 'mannheim germany',
#         'warsaw poland', 'ostende belgium', 'croydon united', 'munich germany',
#         'brindisi italy', 'brindisi harbor italy', 'saint sauveur france',
#         'kasperske hory czechoslovakia', 'frankfurt germany',
#         'bozeman montana', 'pago pago u.s.', 'north pine ontario',
#         'off san clemente island california', 'kandalaksha russia',
#         'marseille france', 'guadalupe mexico', 'mediterranean sea',
#         'ala littoria sa', 'pontoise france', 'near wawona cailifornia',
#         'datia india', 'somerton australia', 'corsavy france',
#         'near formia italy', 'balbuena mexico', 'mangere new',
#         'near saugus california', 'sao paulo brazil', 'cleveland ohio',
#         'alberno canal bc', 'langeoog germany', 'near singida tanzania',
#         'mount mercedario chile', 'billings montana', 'off sardinia italy',
#         'andes', 'panagra', 'stulpica romania', 'kisumu kenya',
#         'pacific ocean between manila and guam', 'pan american world airways',
#         'debrecen hungary', 'shishijima japan', 'near san andres tuxtla vera',
#         'kiel germany', 'guanabara brazil', 'montnago italy',
#         'bucharest romania', 'wangmoon china', 'tokyo japan', 'innisfail australia',
#         'near tucumcari new', 'off bathurst gambia', 'grisons switzerland',
#         'soest germany', 'mt. dandenong australia', 'somerset england',
#         'channel islands jersey', 'schiphol amsterdam', 'regina saskatchewan',
#         'bathurst gambia', 'bagdad iraq', 'off point reyes california',
#         'mexico city mexico', 'off kuba island okinawa', 'amsterdam netherlands',
#         'darwin australia', 'paris france', 'rio de janeiro brazil',
#         'miles city montana', 'katherine australia',
#         'atlantic ocean between n.y. and bermuda', 'imperial airways',
#         'juneau alaska', 'near roubien france', 'haren belgium',
#         'manzanares colombia', 'near adler washington', 'oklahoma city oklahoma',
#         'near marrakech morocco', 'lumbo mozambique', 'near marrakech morocco',
#         'guayaquil ecuador', 'schiphol amsterdam', 'vlissingen the',
#         'forest-in-teesdale. united kingdom', 'british american air services',
#         'konstanz switzerland', 'barcelona spain', 'rio de janerio brazil',
#         'off copenhagen denmark', 'lahore india', 'hannover germany',
#         'north sea', 'klm royal dutch airlines', 'calarmar colombia',
#         'gosport england', 'south of gibraltar', 'iberia airlines',
#         'off malta-luqa', 'british airways', 'mogador morocco',
#         'denpasar indonesia', 'near cosenza italy', 'near bucaramanga colombia',
#         'gulf of oman', 'imperial airways', 'stromboli island italy',
#         'near loch lomond scotland', 'el segundo california',
#         'off prangli island gulf', 'near ouistreham france',
#         'gulf of tonkin', 'air france', 'hannover germany',
#         'near canberra australia', 'gospic', 'cluj romania',
#         'near lovettsville virginia', 'osijek croatia', 'near changyi china',
#         'berlin germany', 'near rincon bolivia', 'near centerville utah',
#         'rio de janeiro brazil', 'brandenburg germany', 'mediterranean sea',
#         'air france', 'chicago illinois', 'capri island italy',
#         'mediterranean sea', 'latio', 'off fernando de noronha brazil',
#         'near nagyvarad hungary', 'near kian china', 'near robertson missouri',
#         'armstrong on', 'atlanta georgia', 'trontheim norway',
#         'elands bay south', 'atlantic ocean',
#         'great western and southern air lines', 'bucharest romania',
#         'sea of japan', 'manchurian air lines', 'rome italy', 'arran scotland',
#         'ayr scotland', 'near sao paulo brazil', 'coen australil',
#         'campbeltown argyll', 'bollemont france', 'san juan puerto',
#         'near petrich bulgaria', 'near moorhead minnesota',
#         'st. thomas ontario', 'chardzhou turkmenistan', 'miami florida',
#         'baiserke kazakhstan', 'sabang indonesia', 'near las vegas nevada',
#         'kupang indonesia', 'kupang timor', 'near kupang timor',
#         'english channel near', 'zhengzhou-xinzheng china',
#         'off belmont brisbane', 'indian ocean', 'british overseas airways',
#         'off broome australia', 'wyndham australia', 'kunming china',
#         'pine creek australia', 'salt lake city utah', 'miles city montana',
#         'near rome italy', 'near premier west', 'off broken head australia',
#         'llanfair england', 'algiers algeria?', 'deutsche lufthansa',
#         'trinidad', 'klm royal dutch airlines', 'near dunbeath scotland',
#         'off west africa', 'british overseas airways', 'ameur el ain algeria',
#         'near sao paulo brazil', 'near coamo puerto',
#         'botwood newfoundland', 'budapest romania', 'yanaul russia',
#         'palm springs california', 'la esperanza colombia', 'norway',
#         'military - royal air force', 'near kranoyarsk russia',
#         'near tashkent russia', 'fairfield utah', 'near vienna austria',
#         'near chilliwack british', 'near cabo ruivo marine',
#         'near paramarino dutch', 'off the brazilian coast', 'ukiah california',
#         'near chaparra peru', 'near gander newfoundland', 'seattle washington',
#         'lisbon portugal', 'luishui china', 'himalaya china',
#         'archerfield aerodrome queensland', 'north sea',
#         'british overseas airways', 'off port moresby new',
#         'off the coast of france', 'british overseas airways',
#         'red springs north', 'noumea', 'near mackay old', 'khartoum sudan',
#         'khartoum sudan', 'gibraltar?', 'naknek afb alaska',
#         'brandon head ireland', 'trammel kentucky', 'ploesti romania',
#         'off townsville australia', 'fort hertz china', 'rhodes greece',
#         'rio de janeiro brazil', 'north sea', 'ab aerotransport',
#         'off galveston texas', 'near maxton north', 'near calcutta india',
#         'near centerville tennessee', 'st. donat quebec', 'columbus georgia',
#         'hallo sweden', 'eastern libya', 'british overseas airways',
#         'poona india', 'kunming china', 'kunming china', 'port moresby new',
#         'off montrose scotland', 'suifu china', 'canal creek australia',
#         'lakeside utah', 'belgrad yugoslavia', 'near quelimane mozambique',
#         'memphis tennessee', 'china', 'china national aviation corporation',
#         'eubeoa greece', 'new guinea', 'military - u.s. army',
#         'near nome alaska', 'belgrad yugoslavia', 'frederikstad norway',
#         'montreal canada', 'between calcutta to dinjan china',
#         'off calcutta india', 'carentan france', 'barneville france',
#         'flamanville france', 'kunming china', 'kweilin china',
#         'porto alegre brazil', 'portland maine', 'nineteen miles w of kokoda papua',
#         'north atlantic ocean', 'military - u.s. army air forces',
#         'port logan scotland', 'funafuti gilbert', 'naper nebraska',
#         'off antilla cuba', 'blythburgh england', 'freckelton england',
#         'preswick scotland', 'near lidköping västergötland', 'sao paulo brazil',
#         'belgrad yugoslavia', 'near mossman queensland', 'copeland kansas',
#         'alaska', 'u. s. air force', 'rio doce brazil', 'near dijon france',
#         'near sadiya india', 'bosnia', 'deutsche lufthansa', 'sydney australia',
#         'sydney australia', 'telemark norway', 'komarom', 'birkenhead england',
#         'hanford california', 'jacksonville florida', 'near kumming yunan',
#         'lewes england', 'nairobi kenya', 'tegucigalpa nicaragua',
#         'off falsterbo sweden', 'dinjan china', 'van nuys california',
#         'atlantic ocean', 'trans-canada air lines', 'orlivka ukraine',
#         'english channel', 'military - u.s. army air forces',
#         'near dinjan india', 'port of spain trinidad', 'burbank california',
#         'china', 'china national aviation corporation', 'near kunming china',
#         'timor indonesia', 'redesdale australia', 'near montieri italy',
#         'nunters burgh england', 'off oakland california',
#         'lagoa santa brazil', 'casablanca morocco', 'snezka mountains poland',
#         'marion virginia', 'coral sea off', 'kunming china',
#         'morgantown west', 'near perth australia', 'near steinreich germany',
#         'sweetwater texas', 'near piesenkofen germany', 'north barrule isle',
#         'washington d.c.', 'page airways', 'manus island new',
#         'hindhead england', 'roye france', 'iran jayas new',
#         'off drewin ivory', 'china', 'china national aviation corporation',
#         'gealdton australia', 'swanage england', 'bangalore india',
#         'texas', 'military - u.s. air force', 'north atlantic ocean',
#         'military -royal air force', 'near kisumu kenya',
#         'near florence south', 'new york new', 'near san luis potosi mexico',
#         'fort de france martinique', 'ixtaccihuati mexico',
#         'florence south', 'near milne bay new', 'near kansas missouri',
#         'puncak jaya papua', 'near chihkiang china', 'elvetham england',
#         'lakeland florida', 'rennes france', 'melsbroek belgium',
#         'near peking china', 'timor sea atlantic',
#         'between shanghi and canton china', 'near chiringa india',
#         'valetta malta', 'tarapoto peru', 'chihchiang china',
#         'herrenalb germany', 'near chuka india', 'near grants new',
#         'off corpus christi texas', 'near boccadi italy',
#         'near picinisco italy', 'near castel libya', 'himalayas',
#         'military - u.s. army', 'near tacloban philippines',
#         'near jacquinot bay new guinea', 'military - royal australian air force',
#         'white\'s farm england', 'near rochefort france', 'off smyrna bahamas',
#         'off the florida coast', 'military - u.s. navy',
#         'near billings montana', 'voksenkollen norway', 'bangui french',
#         'near dudinka russia', 'new york city new', 'birmingham alabama',
#         'changchun china', 'near netrubezh russia', 'marseilles france',
#         'cheshire connecticut', 'crowsnest pass alberta', 'near le mans france',
#         'mt. elk wyoming', 'negros philippines', 'charlottetown pe',
#         'live oak springs california', 'near prague czechoslovakia',
#         'off hobart tasmania', 'near nanking china', 'hobart mills california',
#         'off ceylon cocos', 'near craigavad northern', 'rabat malta',
#         'near shensi china?', 'la liberiad nicaragua', 'pindi-khut -',
#         'munson florida', 'richmond virginia', 'oslo norway',
#         'off amalfi italy', 'near abeokuta nigeria', 'taboga island panama',
#         'pau france', 'off malaya', 'military - royal air force',
#         'holyoke massachusetts', 'reading pennsylvania', 'tsinan china',
#         'cuenca ecuador', 'goodland kansas', 'off the panama coast',
#         'military - (2) u.s. army air forces', 'bassein burma',
#         'near huatesco veracruz', 'oslo norway', 'lakehurst new',
#         'malta-luqa malta', 'rouen france', 'moline illinois', 'cairo egypt',
#         'near prince rupert british', 'holtug denmark', 'le bourget france',
#         'elko nevada', 'nome alaska', 'bathurst gambia',
#         'estevan saskatchewan', 'brussels belgium', 'near gander newfoundland',
#         'near tripoli libya', 'lochi mountain china',
#         'near hong kong international airport', 'military - royal air force',
#         'rio doce brazil', 'near milngavie stirlingshire',
#         'stephenville newfoundland', 'off penang malaya',
#         'apeldoorn the', 'cheyenne wyoming', 'near sefrou morocco',
#         'near chitral india', 'laramie wyoming', 'gebel kalamoun egypt',
#         'st leger-la-montagne france', 'near moscow russia',
#         'cleveland ohio', 'lebec california', 'near cofre de perote mexico',
#         'amsterdam netherlands', 'north pacific ocean',
#         'military - u.s. army air forces', 'san jose costa',
#         'el palomar argentina', 'meshed iran', 'near osaka japan',
#         'toledo washington', 'mt. banahaur philippines', 'caribbean atlantic',
#         'near rio de janeiro brazil', 'near san diego california',
#         'shanghai china', 'near shanghai china', 'near wusong jiangsu',
#         'walshville illinois', 'michigan city indiana', 'near shannon ireland',
#         'sao paulo brazil', 'tsingtao china', 'carmel new',
#         'off laoag china', 'near lympne england', 'near galax virginia',
#         'near puebla mexico', 'puesto araujo colombia', 'chongqing china',
#         'hong kong', 'philippine air lines', 'croydon surrey',
#         'copenhagen denmark', 'near hankow china', 'near lisbon portugal',
#         'harrington delaware', 'pedro bernardo spain', 'denver colorado',
#         'near bogota colombia', 'off terracina italy', 'chungking china',
#         'china sea pacific', 'near georgia ussr', 'aeroflot',
#         'cordillera colombia', 'l\'isola di ischia italy',
#         'mt. moucherolles france', 'near medellin colombia',
#         'negombo sri', 'near caracas venezuela', 'off dakar senegal',
#         'columbus georgia', 'near vancouver british',
#         'near nicoya guanacaste', 'delaware bay new', 'near khabarovsk russia',
#         'hjedinsfjordur iceland', 'atsugi japan', 'la guardia airport queens',
#         'port deposit maryland', 'near gemenos france', 'near natal brazil',
#         'leesburg virginia', 'al mayadin syria', 'black sea gulf',
#         'near eaeka french', 'melbourne florida', 'vichy cargo',
#         'az-zubair iran', 'moron argentina', 'near yumen china',
#         'andes argentina', 'north pacific ocean', 'military - u.s. navy',
#         'new york new', 'malmo sweden', 'bucharest romania',
#         'hanksville utah', 'bahrain persian', 'harsiad norway',
#         'near el paso texas', 'ocean 800', 'sylva north',
#         'off cartegena spain', 'bryce canyon utah', 'annette island alaska',
#         'near mt. hymettus greece', 'near srinagar india',
#         'off barrio rizal philippines', 'gallup new', 'near bouchox france',
#         'newcastle delaware', 'ravello italy', 'phouznicie romania',
#         'yakutat alaska?', 'china national aviation corporation',
#         'montenegrin mountains yugoslavia', 'near trappa italy',
#         'seattle washington', 'near goose bay labrador',
#         'near memphis tennessee', 'krasnoyarsk russia', 'kunming china',
#         'korangi creek india', 'leon mexico', 'ruislip england',
#         'paris france', 'near savannah georgia', 'near palestro algeria',
#         'ciudad havajillo dominican', 'oxon hill maryland',
#         'near mukden china', 'diablo mts. california', 'atlantic ocean ne',
#         'off jacksonville florida', 'near padalarang indonesia',
#         'ubrichstein germany', 'collesalvetti', 'off st. marcouf france',
#         'davao philippines', 'columbus ohio', 'near belem brazil',
#         'off perpignan france', 'heathrow airport london',
#         'near skalafell iceland', 'chicago illinois', 'mt. sanford alaska',
#         'sierra cristais brazil', 'villa pinzon colombia',
#         'monte cardo corsica', 'near berlin germany', 'kano nigeria',
#         'shannon ireland', 'territory of new guinea',
#         'new guinea air traders', 'near irkutsk russia', 'aeroflot',
#         'near magazini belgian', 'mount coron france', 'vrede south',
#         'columbus ohio', 'near bovingdon england', 'khabarovsk russia',
#         'albacete spain', 'isle of man', 'hargreaves airways',
#         'over the pearl river china', 'mount carmel pennsylvania',
#         'maiquetia venezuela', 'keerbergen belgium', 'northolt middlesex',
#         'djiring french', 'belem brazil',
#         'pacific ocean between hong kong and macao', 'cathay pacific airways',
#         'cap-des-rosiers quebec', 'buenos aires argentina', 'tsingtao china',
#         '1 miles', 'karachi pakistan', 'port underwood new',
#         'la guaira venezuela', 'near winona minnesota',
#         'near elizabethville belgium', 'near quirindi australia',
#         'balkhash kazakhstan', 'near trondheim norway',
#         'near yevlakh azerbaijan', 'prestwick airport scotland',
#         'mt. ruapehu new', 'georgian ssr ussr', 'aerflot',
#         'near edmonton alberta', 'near glossop england',
#         'cape spencer alaska', 'mt. macedon australia', 'liverpool england',
#         'near ryzhovo russia', 'vehari pakistan', 'kiangwan china',
#         'milan italy', 'taipei taiwan', 'near bogata colombia',
#         'near pilos greece', 'basalt island hong', 'near madrid spain',
#         'off san juan puerto', 'mt. argentari italy', 'seattle washington',
#         'caravelas bay brazil', 'brandywine maryland', 'near pelotas brazil',
#         'ras-el-tin egypt', 'near srinagar india',
#         'near succoth glen lochgoilhead', 'atlantic ocean off',
#         'homer alaska', 'port washington new', 'trinity bay newfoundland',
#         'castel benito libya', 'buenaventura bay colombia',
#         'off copenhagen denmark', 'near huanuco peru', 'near coventry warks',
#         'braemar resevoir hong', 'near cuzco peru', 'coolangatta australia',
#         'berlin germany', 'near waikanae new', 'near mironovo russia',
#         'near portland dorset', 'superga italy', 'sibuyan sea off',
#         'near novosibirsk russia', 'malahasa attica greece',
#         'near florianpolis brazil', 'san juan puerto', 'off bari italy',
#         'near guildford australia', 'chatsworth california',
#         'near bombay india', 'seattle washington', 'marga russia',
#         'chesterfield new', 'jaquirana brazil', 'sao francisco bay brazil',
#         'salasaca ecuador', 'salalah oman', 'near bogota colombia',
#         'off lurga point ireland', 'near oldham england',
#         'near bigstone lake manitoba', 'leopoldville zaire',
#         'sault-aux-cochons pq', 'mt. popocatepetl mexico',
#         'near castilla argentina', 'cheyenne wyoming',
#         'san miguel island azores', 'arlington virginia', 'akron ohio',
#         'calcutta india', 'near oslo norway', 'near bucaramanga colombia',
#         'chaleyssin france', 'dallas texas', 'taquaracucu brazil',
#         'vallejo california', 'near lanchow china', 'near hoikow china',
#         'washington d.c. capital', 'jungshahi pakistan', 'orizaba mexico',
#         'aulnay-sous-bois france', 'comilla pakistan', 'sverdlovsk russia',
#         'albacete spain', 'near vacas bolivia', 'iloilo air',
#         'near tamatave madagascar', 'near snag yukon', 'north sea',
#         'klm royal dutch airlines', 'near prague czechoslovakia',
#         'minneapolis minnesota', 'saigon vietnam',
#         'llandow airport cardiff', 'ankara turkey', 'off cap-ferret france',
#         'hatiara india', 'near hastings england', 'santa ana colombia',
#         'near atsugi japan', 'chimborazo ecuador', 'lagens air force base azores',
#         'myrtle beach south', 'near pasto colombia', 'teterboro new',
#         'near ilheus brazil', 'atlantic ocean off florida',
#         'westair transport', 'near fonseca colombia', 'off bahrain',
#         'air france', 'bahrain', 'air france', 'bahrain bahrain',
#         'lake michigan 18', 'york australia', 'busan south',
#         'casablanca morocco', 'near pathankot india', 'near bocoio angola',
#         'myrtle beach north', 'off o-shima island japan',
#         'porte alegre brazil', 'tunbukta algeria', 'algrete brazil',
#         'karaganda russia', 'near fairfield california',
#         'near eagle colorado', 'kampong jenera malaysia',
#         'near wadi natrun egypt', 'utica new', 'tehran iran',
#         'kwajalein marshall', 'near zagreb yugoslavia', 'karlstad sweden',
#         'near kyushu island japan', 'almelund minnisota',
#         'casablanca morocco', 'london england', 'london heathrow england',
#         'mont blanc france', 'near butte montana',
#         'mt. tete de l\'obiou france', 'surabaya indonesia',
#         'near moran junction wyoming', 'cuzco peru', 'khitka bhutan',
#         'near chamaran iran', 'bangui french', 'ruig piner france',
#         'londrina brazil', 'katagiri india', 'ribeirao brazil',
#         'valera venezuela', 'near baguio philippines', 'penticton british',
#         'santiago del estado argentina', 'ixopo south', 'mt. bukit besar',
#         'philadelphia pennsylvania', 'near reardan washington',
#         'near civitavecchia italy', 'near an tung taiwan',
#         'off hafnarfjorour iceland', 'off terceira portugal',
#         'near mt. cameroon bue', 'yali colombia', 'sioux city iowa',
#         'mt. butler hong', 'corozal colombia', 'off florianopolis brazil',
#         'over the north atlantic', 'military - u.s. air force',
#         'irkutsk russia', 'rio grande argentina', 'manchester england',
#         'bogota colombia', 'refugio pass near', 'near charleston west',
#         'cape d\'arguilar hong', 'key west florida', 'fort wayne indiana',
#         'near albuquerque new', 'bordeaux france', 'rancharia',
#         'new boston texas', 'rio de janeiro brazil', 'medellin colombia',
#         'near sanoyea liberia', 'near rijeka yugoslavia',
#         'rocky mountain nat. park near', 'aracaju brazil',
#         'lyneham afb england', 'near tezpur india', 'off lae new',
#         'thudamot china', 'near sitka alaska', 'gao mali',
#         'cochabamba bolivia', 'barilla bay australia', 'moisville france',
#         'ubatuba brazil', 'decoto california', 'sao paulo brazil',
#         'off redwood city california', 'off ialas baeares spain',
#         'bangalore india', 'near tachikawa air base',
#         'military - us air force', 'la paz bolivia', 'cerro blanco mexico',
#         'north atlantic', 'military - u.s. air force',
#         'east griqualand south', 'mt. benson bc', 'skopje yugoslavia',
#         'near flores guatemala', 'near tucumcari new', 'puy-de-dôme france',
#         'near lodz poland', 'near novosibirsk russia', 'cairo egypt',
#         'calcutta india', 'zurich switzerland', 'san luis acatlan mexico',
#         'denver colorado', 'yaramunda papua', 'elizabeth new',
#         'tehran iran', 'near namtso russia', 'near little valley new',
#         'near fairbanks alaska', 'near phoenix arizona', 'calcutta india',
#         'andapa madagascar', 'com edno ireland', 'off sandspit bc',
#         'elizabeth new', 'kikwit belgian', 'kaneko japan',
#         'elizabeth new', 'near burgio italy', 'near yaounde cameroon',
#         'nagpur india', 'uberlandia', 'nice france', 'cebu philippines',
#         'near sequin texas', 'frankfurt germany', 'near gaspe quebec',
#         'near gao french', 'moscow russia', 'near san felipe venezuela',
#         'baguio philippines', 'new york new', 'mihara volcano japan',
#         'agartala india', 'north of san juan puerto',
#         'near whittier california', 'near carolina brazil', 'delhi',
#         'near skien norway', 'ipoh malaysia', 'sao paulo brazil',
#         'near manaus brazil', 'near atar mauritania', 'baltic sea',
#         'swedish air force', 'near brighton east', 'lakenheath afb england',
#         'off northumberland north', 'whiting field near',
#         'off rio de janeiro brazil', 'palmeira de goias brazil',
#         'off trapani italy', 'near khewra west', 'kosti sudan',
#         'near farnsborough england', 'san blas panama', 'wadi halfa sudan',
#         'skvoritsy russia', 'off tarbat ness scotland',
#         'san fransisco do paula brazil', 'off kangnung south',
#         'near flagstaff arizona', 'lake chad chad', 'near summit alaska',
#         'near seoul south', 'near anchorage alaska', 'shepard montana',
#         'mount gannett alaska', 'near tacoma washington',
#         'off bermuda-kindley field bermuda', 'near sofia bugaria',
#         'moses lake washington', 'off miami florida', 'tehran iran',
#         'off caracas venezuela', 'chinmen island taiwan',
#         'belfast northern', 'fish haven idaho', 'issaquah washington',
#         '25 nm off agrigento italy', 'sinnai sardinia',
#         'off newfoundland canada', 'lai chau vietnam', 'bordeaux france',
#         'cairo egypt', 'off mobile alabama', 'karachi pakistan',
#         'windsor locks connecticut', 'kalasahar india',
#         'off da nang vietnam', 'random island newfoundland',
#         'stephenville newfoundland', 'u.s.', 'alvarado california',
#         'itapebi brazil', 'mtara tanganyika', 'off kingston jamaica',
#         'miandivazo madagascar', 'near guwahati india',
#         'selleck washington', 'nw of hanoi vietnam',
#         'san francisco bay california', 'near jalalogori west',
#         'off hartland point england', 'new delhi india',
#         'prince rupert bc', 'near marshall texas', 'st. louis missouri',
#         'amsterdam netherlands', 'goose wade russia', 'near zugdidi georgia',
#         'near reo copiapo chile', 'san ramon mtns. costa',
#         'mount phou-lassy french', 'sao paulo brazil',
#         'tachikawa afb tokyo', 'pacific ocean 325', 'near milton florida',
#         'near kanggye north', 'off fethiye point turkey', 'sharjah united',
#         'off irish coast', 'military - u.s. air force',
#         'near san diego california', 'near barcelonnette france',
#         'vail washington', 'san andres honduras', 'chablekal mexico',
#         'albany new', 'ankara turkey', 'louisville kentucky',
#         'frankfurt germany', 'lai chau vietnam', 'near monterrey mexico',
#         'new york city new', 'near magadan russia',
#         'near half moon bay california', 'kharkov. ukraine russia',
#         'tarabuco bolivia', 'off argyll scotland', 'near guaderrama spain',
#         'nagpur india', 'near cairo egypt', 'tecpan mt. guatemala',
#         'guam mariana', 'zurich switzerland', 'dah-el-kadeeb syria',
#         'herat afghanistan', 'lapseki turkey', 'near aldbury england',
#         'off elba italy', 'manizales colombia', 'prague czech',
#         'signal hill california', 'rome italy', 'kansas city missouri',
#         'off hokkaido japan', 'susitna valley alaska', 'off gozo malta',
#         'new delhi india', 'wright wyoming', 'near st. etienne de tinee france',
#         'kallang airport singapore', 'off mackay australia',
#         'near lothian maryland', 'monterrey mexico', 'kabassaak turkey',
#         'hanoi vietnam', 'off stromboli italy', 'moose jaw sk',
#         'batuco chile', 'xieng kouang laos', 'sierra del vilgo argentina',
#         'near calcutta india', 'paraparaumu new', 'cipo mountain brazil',
#         'near maribor slovenia', 'sao paulo brazil', 'da nang vietnam',
#         'off folkestone england', 'near salvador brazil',
#         'off hainan island china', 'near mcgrath alaska',
#         'terceira island azores', 'vietnam', 'autrex', 'near pakse laos',
#         'near mason city iowa', 'off ijuuiden north',
#         'sakhalin oblast russia', 'rapid city south', 'foynes ireland',
#         'off rio de janeiro brazil', 'cairo egypt', 'novosibirsk russia',
#         'near nice italy', 'krasnoyarsk territory russia',
#         'off ocean city maryland', 'mangalore australia',
#         'jirishanga de', 'berlin new', 'near luang pragang laos',
#         'bratislava slovakia', 'new york new', 'near bolivar venezuela',
#         'pittsburgh pennsylvania', 'prestwick ayrshire',
#         'irkutsk russia', 'near anchorage alaska', 'off skellings ireland',
#         'greater cincinnati airport covington', 'london ontario',
#         'des moines iowa', 'lapadrera colombia', 'nagpur india',
#         'near calabar nigeria', 'abruzzio mountains italy',
#         'albuquerque new', 'salisbury', 'formosa argentina',
#         'devitoria da conquista brazil', 'near cuidad de valles mexico',
#         'mascota mexico', 'trujillo colombia', 'springfield missouri',
#         'oahu hawaii', 'off the oregon coast', 'pan american world airways',
#         'off pensacola florida', 'islip new',
#         'off great natuna island sarawak', 'kupe mountains cameroons',
#         'mt. kilimanjaro kenya', 'off barcelona venezuela',
#         'edmonton alberta', 'fort lamy cameroon', 'near asuncion paraguay',
#         'leon mexico', 'oaxaca mexico', 'chicago illinois',
#         'near petrich bulgaria', 'fort leonard wood missouri',
#         'near voronezh russia', 'near edelweiler west',
#         'caparao mountain brazil', 'simra nepal', 'lanywa burma',
#         'burbank california', 'near banyo cameroon',
#         'near thorhild alberta', 'idris libya',
#         'pacific ocean (1 miles', 'yellowknife northwest',
#         'pico oiriruma-vinac peru', 'near centennial wyoming',
#         'near vienna austria', 'longmont colorado',
#         'near las vegas nevada', 'seattle washington', 'iwo jima japan',
#         'near ballico california', 'belem brazil',
#         'khabarovsk territory russia', 'hollywood south',
#         'sao paulo brazil', 'jacksonville florida', 'frederick henry bay',
#         'oreway newfoundland', 'torysa czechoslovakia', 'lyon france',
#         'frobisher bay canada', 'near fort chimo quebec',
#         'near niles california', 'near zurrieg malta', 'near cairo egypt',
#         'near aleppo syria', 'jalkot pakistan', 'tezpur india',
#         'largs england', 'korat -', 'indapur india',
#         'pittsburgh pennsylvania', 'seattle washington',
#         'skilak lake alaska', 'parintins brazil', 'london england',
#         'kathmandu nepal', 'orleans ontario', 'guatemala city guatemala',
#         'asbury park new', 'kano nigeria', 'grand canyon arizona',
#         'near flat rock michigan', 'near brows mills new',
#         'shannon ireland', 'rio cuarto argentina', 'thazi burma',
#         'cold bay alaska', 'amman jordan', 'bartlesville oklahoma',
#         'near nome alaska', 'off land\'s end england',
#         'over the pacific ocean', 'pan american world airways',
#         'agartala india', 'over the mediterranean sea',
#         'military - egyptian air force', 'blackbushe england',
#         'hommelfjell norway', 'puerto somoza nicaragua',
#         'el rucio mountain colombia', 'paris france',
#         'near eglisau switzerland', 'caracas venezuela', 'caqueta colombia',
#         'near chilliwack british', 'dannemois france', 'grub germany',
#         'mt. giner italy', 'dhahran saudi', 'owasso oklahoma',
#         'near buenos aires argentina', 'ometepe island nicaragua',
#         'paris france', 'near sunland california', 'new york new',
#         'kimpo air base south', 'blyn washington', 'near miho ab japan',
#         'drayton england', 'el soldado colombia', 'manchester england',
#         'near cebu philippines', 'near sayari bolivia',
#         'over the north pacific ocean', 'military - u.s. air force',
#         'bage brazil', 'algiers algeria', 'anchieta island brazil',
#         'merida mexico', 'near el quweira jordan', 'blackbushe hants',
#         'santoshpur india', 'barajas madrid',
#         'near san carlos de bariloche argentina',
#         'narsarressuak greenland', 'new delhi india', 'near moscow russia',
#         'bodensee switzerland', 'near clarksburg maryland',
#         'port hardy bc', 'bay of bengal pakistan', 'near fort rupert quebec',
#         'near biak indonesia', 'near hsinchu taiwan',
#         'daggett california', 'near issoudun quebec', 'copenhagen denmark',
#         'assam india', 'near juticalpa honduras', 'niquitao venezuela',
#         'new bedford massachusetts', 'montevideo', 'bhiwandi maharashtra',
#         'islay-glenegedale airport scotland', 'akshi russia',
#         'beirut lebanon', 'porto alegre brazil', 'belfast ireland',
#         'madrid spain', 'near campeche mexico', 'dusseldorf west',
#         'moscow russia', 'bristol england', '900 miles e of honolulu hawaii',
#         'chessell down england', 'near palma de mallorca spain',
#         'christchurch new', 'bolivar argentina', 'jeannine lake quebec',
#         'ozamis city philippines', 'near birobidzhan russia',
#         'stansted england', 'off oahu hawaii', 'buenos aires argentina',
#         'belem brazil', 'near la paz bolivia', 'rio de janeiro brazil',
#         'norwalk california', 'munich germany', 'mount vesuvius italy',
#         'cairo egypt', 'raiatea french', 'off corvo island azores',
#         'horwich lancs', 'menzalah lake egypt', 'off ryukyu islands okinawa',
#         'grants new', 'near kathmandu nepal', 'miami florida',
#         'bridgeport texas', 'quito ecuador', 'freeland michigan',
#         'mt. illiniza ecuador', 'off castell de fels spain',
#         'near sloan 10', 'new delhi india', 'chatenoy france',
#         'near casablanca morocco', 'brunswick maryland', 'gurgaon india',
#         'sw of algiers algeria', 'rio de janeiro brazil',
#         'near guadalajara mexico', 'manila philippines',
#         'martinsburg west', 'magadan oblast russia',
#         'ilha grande rio de janeiro', 'aerolenas argentinas',
#         'curitiba brazil', 'mohanbari india',
#         'near chicopee falls massachusetts', 'dhaka baangladesh',
#         'benghazi libya', 'near belem brazil loide', 'sakiya saugye j'
#     ]
# }


# countries_keywords = {
#     'united states': 'USA', 'us': 'USA', 'america': 'USA', 'virginia': 'USA', 'ohio': 'USA', 'pennsylvania': 'USA', 'iowa': 'USA', 'maryland': 'USA', 'new jersey': 'USA', 'wyoming': 'USA', 'illinois': 'USA', 'wisconsin': 'USA', 'nevada': 'USA', 'california': 'USA', 'kentucky': 'USA', 'tennessee': 'USA', 'oregon': 'USA', 'texas': 'USA', 'mississippi': 'USA', 'maine': 'USA', 'georgia': 'USA', 'alaska': 'USA', 'florida': 'USA', 'arizona': 'USA', 'new mexico': 'USA', 'oklahoma': 'USA', 'montana': 'USA', 'idaho': 'USA', 'minnesota': 'USA', 'arkansas': 'USA', 'connecticut': 'USA', 'massachusetts': 'USA', 'washington': 'USA', 'delaware': 'USA', 'michigan': 'USA', 'south carolina': 'USA', 'north carolina': 'USA', 'colorado': 'USA', 'kansas': 'USA', 'nebraska': 'USA', 'missouri': 'USA', 'new hampshire': 'USA', 'vermont': 'USA', 'rhode island': 'USA', 'hawaii': 'USA',

#     'germany': 'Germany', 'belgium': 'Belgium', 'france': 'France', 'england': 'United Kingdom', 'united kingdom': 'United Kingdom', 'uk': 'United Kingdom', 'scotland': 'United Kingdom', 'ireland': 'Ireland', 'denmark': 'Denmark', 'netherlands': 'Netherlands', 'australia': 'Australia', 'morocco': 'Morocco', 'romania': 'Romania', 'russia': 'Russia', 'ussr': 'Russia', 'colombia': 'Colombia', 'georgia': 'Georgia', 'spain': 'Spain', 'hungary': 'Hungary', 'mauritania': 'Mauritania', 'algeria': 'Algeria', 'uruguay': 'Uruguay', 'mexico': 'Mexico', 'greece': 'Greece', 'cuba': 'Cuba', 'iran': 'Iran', 'madagascar': 'Madagascar', 'argentina': 'Argentina', 'bulgaria': 'Bulgaria', 'canada': 'Canada', 'thailand': 'Thailand', 'iraq': 'Iraq', 'lebanon': 'Lebanon', 'bolivia': 'Bolivia', 'ukraine': 'Ukraine', 'pakistan': 'Pakistan', 'egypt': 'Egypt', 'switzerland': 'Switzerland', 'italy': 'Italy', 'poland': 'Poland', 'chile': 'Chile', 'trinidad': 'Trinidad and Tobago', 'norway': 'Norway', 'croatia': 'Croatia', 'tajikistan': 'Tajikistan', 'libya': 'Libya', 'gambia': 'Gambia', 'sudan': 'Sud
Chad', 'oman': 'Oman', 'qatar': 'Qatar', 'uae': 'United Arab Emirates', 'saudi arabia': 'Saudi Arabia', 'yemen': 'Yemen', 'kuwait': 'Kuwait', 'bahrain': 'Bahrain', 'iraq': 'Iraq', 'jordan': 'Jordan', 'lebanon': 'Lebanon', 'syria': 'Syria', 'palestine': 'Palestine', 'israel': 'Israel', 'cyprus': 'Cyprus', 'maldives': 'Maldives', 'nepal': 'Nepal', 'bhutan': 'Bhutan', 'sri lanka': 'Sri Lanka', 'brunei': 'Brunei', 'east timor': 'East Timor', 'laos': 'Laos', 'cambodia': 'Cambodia', 'myanmar': 'Myanmar', 'thailand': 'Thailand', 'vietnam': 'Vietnam', 'malaysia': 'Malaysia', 'singapore': 'Singapore', 'philippines': 'Philippines', 'indonesia': 'Indonesia', 'australia': 'Australia', 'new zealand': 'New Zealand', 'fiji': 'Fiji', 'samoa': 'Samoa', 'tonga': 'Tonga', 'vanuatu': 'Vanuatu', 'solomon islands': 'Solomon Islands', 'kiribati': 'Kiribati', 'nauru': 'Nauru', 'palau': 'Palau', 'micronesia': 'Micronesia', 'marshall islands': 'Marshall Islands', 'tuvalu': 'Tuvalu', 'niue': 'Niue', 'cook islands': 'Cook Islands', 'tokelau': 'Tokelau', 'wallis and futuna': 'Wallis and Futuna', 'new caledonia': 'New Caledonia', 'french polynesia': 'French Polynesia', 'pitcairn islands': 'Pitcairn Islands', 'norfolk island': 'Norfolk Island', 'christmas island': 'Christmas Island', 'cocos (keeling) islands': 'Cocos (Keeling) Islands', 'heard island and mcdonald islands': 'Heard Island and McDonald Islands', 'south georgia and the south sandwich islands': 'South Georgia and the South Sandwich Islands', 'bouvet island': 'Bouvet Island', 'svalbard and jan mayen': 'Svalbard and Jan Mayen', 'faroe islands': 'Faroe Islands', 'åland islands': 'Åland Islands', 'guernsey': 'Guernsey', 'jersey': 'Jersey', 'isle of man': 'Isle of Man', 'gibraltar': 'Gibraltar', 'akrotiri and dhekelia': 'Akrotiri and Dhekelia', 'bermuda': 'Bermuda', 'cayman islands': 'Cayman Islands', 'falkland islands': 'Falkland Islands', 'montserrat': 'Montserrat', 'turks and caicos islands': 'Turks and Caicos Islands', 'british virgin islands': 'British Virgin Islands', 'anguilla': 'Anguilla', 'saint helena, ascension and tristan da cunha': 'Saint Helena', 'british indian ocean territory': 'British Indian Ocean Territory', 'christmas island': 'Christmas Island', 'cocos (keeling) islands': 'Cocos Islands', 'norfolk island': 'Norfolk Island', 'christmas island': 'Christmas Island', 'cocos (keeling) islands': 'Cocos Islands', 'norfolk island': 'Norfolk Island', 'australian antarctic territory': 'Australia', 'british antarctic territory': 'United Kingdom', 'french southern and antarctic lands': 'France', 'new zealand ross dependency': 'New Zealand', 'norway queen maud land': 'Norway', 'united states pacific remote islands': 'USA', 'united states virgin islands': 'USA',

#     ]

# # Create DataFrame
# df = pd.DataFrame(df)

# country_mapping = {
#     'united states': 'USA', 'usa': 'USA', 'america': 'USA', 'us': 'USA',
#     'virginia': 'USA', 'ohio': 'USA', 'pennsylvania': 'USA', 'iowa': 'USA',
#     'maryland': 'USA', 'new jersey': 'USA', 'wyoming': 'USA', 'illinois': 'USA',
#     'wisconsin': 'USA', 'nevada': 'USA', 'california': 'USA', 'kentucky': 'USA',
#     'tennessee': 'USA', 'oregon': 'USA', 'texas': 'USA', 'mississippi': 'USA',
#     'maine': 'USA', 'georgia': 'USA', 'alaska': 'USA', 'florida': 'USA',
#     'arizona': 'USA', 'new mexico': 'USA', 'oklahoma': 'USA', 'montana': 'USA',
#     'idaho': 'USA', 'minnesota': 'USA', 'arkansas': 'USA', 'connecticut': 'USA',
#     'massachusetts': 'USA', 'washington': 'USA', 'delaware': 'USA', 'michigan': 'USA',
#     'south carolina': 'USA', 'north carolina': 'USA', 'colorado': 'USA', 'kansas': 'USA',
#     'nebraska': 'USA', 'missouri': 'USA', 'new hampshire': 'USA', 'vermont': 'USA',
#     'rhode island': 'USA', 'hawaii': 'USA', 'd.c.': 'USA',

#     'united kingdom': 'United Kingdom', 'uk': 'United Kingdom', 'england': 'United Kingdom', 'scotland': 'United Kingdom',
#     'ireland': 'Ireland', 'northern ireland': 'United Kingdom', 'wales': 'United Kingdom',

#     'germany': 'Germany', 'france': 'France', 'belgium': 'Belgium', 'denmark': 'Denmark',
#     'netherlands': 'Netherlands', 'australia': 'Australia', 'morocco': 'Morocco',
#     'romania': 'Romania', 'russia': 'Russia', 'ussr': 'Russia', 'colombia': 'Colombia',
#     'georgia': 'Georgia', 'spain': 'Spain', 'hungary': 'Hungary', 'mauritania': 'Mauritania',
#     'algeria': 'Algeria', 'uruguay': 'Uruguay', 'mexico': 'Mexico', 'greece': 'Greece',
#     'cuba': 'Cuba', 'iran': 'Iran', 'madagascar': 'Madagascar', 'argentina': 'Argentina',
#     'bulgaria': 'Bulgaria', 'canada': 'Canada', 'thailand': 'Thailand', 'iraq': 'Iraq',
#     'lebanon': 'Lebanon', 'bolivia': 'Bolivia', 'ukraine': 'Ukraine', 'pakistan': 'Pakistan',
#     'egypt': 'Egypt', 'switzerland': 'Switzerland', 'italy': 'Italy', 'poland': 'Poland',
#     'chile': 'Chile', 'trinidad': 'Trinidad', 'norway': 'Norway', 'croatia': 'Croatia',
#     'tajikistan': 'Tajikistan', 'libya': 'Libya', 'gambia': 'Gambia', 'sudan': 'Sudan',
#     'papua new guinea': 'Papua New Guinea', 'indonesia': 'Indonesia', 'tanzania': 'Tanzania',
#     'kenya': 'Kenya', 'japan': 'Japan', 'new zealand': 'New Zealand', 'ecuador': 'Ecuador',
#     'mozambique': 'Mozambique', 'sweden': 'Sweden', 'malta': 'Malta', 'finland': 'Finland',
#     'guatemala': 'Guatemala', 'zimbabwe': 'Zimbabwe', 'tunisia': 'Tunisia',
#     'cameroon': 'Cameroon', 'nigeria': 'Nigeria', 'philippines': 'Philippines',
#     'nicaragua': 'Nicaragua', 'jordan': 'Jordan', 'syria': 'Syria', 'kuwait': 'Kuwait',
#     'peru': 'Peru', 'azerbaijan': 'Azerbaijan', 'sri lanka': 'Sri Lanka',
#     'kyrgyzstan': 'Kyrgyzstan', 'oman': 'Oman', 'israel': 'Israel', 'dominican republic': 'Dominican Republic',
#     'yemen': 'Yemen', 'uganda': 'Uganda', 'china': 'China', 'india': 'India',
#     'brazil': 'Brazil', 'panama': 'Panama', 'vietnam': 'Vietnam', 'nepal': 'Nepal',
#     'bangladesh': 'Bangladesh', 'myanmar': 'Myanmar', 'malaysia': 'Malaysia',
#     'hong kong': 'Hong Kong', 'taiwan': 'Taiwan', 'honduras': 'Honduras',
#     'cyprus': 'Cyprus', 'kazakhstan': 'Kazakhstan', 'turkmenistan': 'Turkmenistan',
#     'central african republic': 'Central African Republic', 'comoros': 'Comoros',
#     'reunion': 'Reunion', 'ghana': 'Ghana', 'bosnia': 'Bosnia',
#     'slovenia': 'Slovenia', 'slovakia': 'Slovakia', 'venezuela': 'Venezuela',
#     'costa rica': 'Costa Rica', 'jamaica': 'Jamaica', 'guadeloupe': 'Guadeloupe',
#     'martinique': 'Martinique', 'puerto rico': 'Puerto Rico', 'bermuda': 'Bermuda',
#     'greenland': 'Greenland', 'iceland': 'Iceland', 'gabon': 'Gabon', 'chad': 'Chad',
#     'mali': 'Mali', 'senegal': 'Senegal', 'south korea': 'South Korea', 'singapore': 'Singapore',
#     'turkey': 'Turkey', 'austria': 'Austria', 'latvia': 'Latvia', 'lithuania': 'Lithuania',
#     'montenegro': 'Montenegro', 'serbia': 'Serbia', 'kosovo': 'Kosovo', 'moldova': 'Moldova',
#     'estonia': 'Estonia', 'luxembourg': 'Luxembourg', 'monaco': 'Monaco', 'vatican city': 'Vatican City',
#     'san marino': 'San Marino', 'andorra': 'Andorra', 'liechtenstein': 'Liechtenstein',
#     'isle of man': 'Isle of Man', 'gibraltar': 'Gibraltar', 'caribbean sea': 'Caribbean Sea',

#     # Major oceans/seas
#     'atlantic ocean': 'Atlantic Ocean', 'north atlantic ocean': 'Atlantic Ocean',
#     'mediterranean sea': 'Mediterranean Sea', 'north sea': 'North Sea',
#     'english channel': 'Channel', 'gulf of finland': 'Gulf of Finland',
#     'aegean sea': 'Aegean Sea', 'gulf of oman': 'Gulf of Oman',
#     'gulf of tonkin': 'Gulf of Tonkin', 'sea of japan': 'Sea of Japan',
#     'indian ocean': 'Indian Ocean', 'pacific ocean': 'Pacific Ocean',
#     'gulf of mexico': 'Gulf of Mexico', 'red sea': 'Red Sea',
#     'black sea': 'Black Sea', 'arctic ocean': 'Arctic Ocean', 'southern ocean': 'Southern Ocean'
# }

# # Combine all keywords into a single regex pattern for efficiency
# # Sort by length descending to match longer phrases first (e.g., "United Kingdom" before "Kingdom")
# all_keywords = sorted(country_mapping.keys(), key=len, reverse=True)
# pattern = re.compile(r'\b(' + '|'.join(re.escape(k) for k in all_keywords) + r')\b')

# # Terms to remove before country extraction (noise like "near", "off", "military -")
# noise_terms = [
#     r'\b(near|off|over the|in the|on the|at|around|within|between|from|to|military -|private)\b',
#     r'\b(aero limited|syndicato condor|klm royal dutch airlines|air union|imperial airways|deutsche lufthansa|air france|societa anonima aero expresso italiana|hillman\'s airways|pan american world airways|british overseas airways|fuerzs aerea de chile|china national aviation corporation|british american air services|iberia airlines|british airways|ab aerotransport|trans-canada air lines|new guinea air traders|hargreaves airways|aeroflot|philippine air lines|cathay pacific airways|westair transport|aerolenas argentinas|swedish air force|us aerial mail service|u\.s\. air force|royal air force|royal australian air force|u\.s\. army|u\.s\. army air forces|u\.s\. navy|egyptian air force)\b',
#     r'\b(island|mountains|river|field|bay|pass|cape|gulf|lake|city|harbor|port|valley|hills|coast|territory|air base|airport|afb|international|airport|naval|base)\b',
#     r'(?<!new)\b(york|england|ohio|pennsylvania|jersey|wyoming|illinois|wisconsin|nevada|california|kentucky|tennessee|oregon|texas|mississippi|maine|georgia|alaska|florida|arizona|mexico|oklahoma|montana|idaho|minnesota|arkansas|connecticut|massachusetts|washington|delaware|michigan|south|north|colorado|kansas|nebraska|missouri|hampshire|vermont|rhode island|hawaii)\b', # State names if not preceded by 'new'
#     r'(\?|\.|\(|\)|\-|\'|\"|\s\s+)'
# ]
# noise_pattern = re.compile('|'.join(noise_terms))

# def clean_and_extract_country(location_str):
#     if pd.isna(location_str):
#         return None

#     # Step 1: Standardize case and remove extra spaces/some punctuation early
#     clean_loc = location_str.lower().strip()
#     clean_loc = re.sub(r'[^\w\s]', '', clean_loc) # Keep only alphanumeric and spaces
#     clean_loc = re.sub(r'\s+', ' ', clean_loc).strip() # Reduce multiple spaces to single

#     # Step 2: Apply specific overrides
#     if 'tienen' in clean_loc:
#         return 'Germany' # User-defined override

#     # Step 3: Remove common non-country terms (noise)
#     cleaned_for_match = noise_pattern.sub(' ', clean_loc).strip()
#     cleaned_for_match = re.sub(r'\s+', ' ', cleaned_for_match).strip()

#     # Step 4: Search for country keywords in the cleaned string
#     match = pattern.search(cleaned_for_match)
#     if match:
#         found_keyword = match.group(1)
#         return country_mapping[found_keyword]

#     # Step 5: Fallback for generic state abbreviations that might be left
#     if clean_loc.endswith('ny'): return 'USA'
#     if clean_loc.endswith('bc'): return 'Canada'
#     if clean_loc.endswith('nsw'): return 'Australia'
#     if clean_loc.endswith('qld'): return 'Australia'
#     if clean_loc.endswith('sk'): return 'Canada'
#     if clean_loc.endswith('pe'): return 'Canada'
#     if clean_loc.endswith('on'): return 'Canada'
#     if clean_loc.endswith('qc'): return 'Canada'
#     if clean_loc.endswith('wi'): return 'USA'
#     if clean_loc.endswith('il'): return 'USA'
#     if clean_loc.endswith('nd'): return 'USA'
#     if clean_loc.endswith('sd'): return 'USA'
#     if clean_loc.endswith('ut'): return 'USA'

#     return None 
# df['Cleaned_Location_Country'] = df['Location'].apply(clean_and_extract_country)

# %%
#df
